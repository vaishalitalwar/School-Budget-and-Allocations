# %%
from bs4 import BeautifulSoup, NavigableString, Tag
import pandas as pd
import requests
import os
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service as ChromeService
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.support.ui import Select
from selenium.common.exceptions import NoSuchElementException
import numpy as np
import glob
import time
import re

# %%
chrome_options = webdriver.ChromeOptions()
#save any files in the current working directory
#prefs = {'download.default_directory' : os.getcwd()}
#chrome_options.add_argument("--headless")
#chrome_options.add_experimental_option('prefs', prefs)
service = ChromeService(executable_path=ChromeDriverManager().install())

driver = webdriver.Chrome(service = service, options=chrome_options)

# %%
script = """
return ['span', 'b', 'strong', 'tr td', 'ul li', ].reduce((nodelist, selector) => [...nodelist, ...document.querySelectorAll(selector)] , [])
.filter(e => 
    ['blue','rgb(0, 0, 255)'].includes(getComputedStyle(e).getPropertyValue('color')) && (['bold','bolder'].includes(getComputedStyle(e).getPropertyValue('font-weight')) || getComputedStyle(e).getPropertyValue('font-weight') >= 500)
).map(e => e.innerText)
"""

# %%
def getAllocationCategories(year, driver):
    
    #Navigate to the memorandums page for the given year
    url = 'https://infohub.nyced.org/reports/financial/financial-data-and-reports/school-allocation-memorandums'
    year = str(year)
    driver.get(url)
    link2memorandums = ''
    elements = driver.find_elements(By.CSS_SELECTOR, 'a[target="_blank"]')
    for element in elements:
        if year in element.text:
            link2memorandums = element.get_attribute('href')
            break
    driver.get(link2memorandums)
    
    #Go to the 	School Allocation Memorandums sorted numerically
    driver.find_element(By.XPATH,"//*[contains(text(), 'SAMs by Numbers')]").click()
    
    #Make a list of all the links to allocation memorandums and category titles
    url_prefix = link2memorandums.split('am_')[0]
    urls = []
    categories = []
    page = requests.get(driver.current_url)
    soup = BeautifulSoup(page.text, 'html.parser')
    table = soup.find('table')

    ran = False

    for row in table:
        try:
            #FSF has multiple entries but we only need the memorandum
            for a in row.find_all('a', href=True):
                if a.text == 'Fair Student Funding Memorandum':
                    urls.append(url_prefix + a['href'])
                    categories.append(a.text)
                #After 'Allocation Summary by District' marks the start of memorandum links
                if 'Allocation Summary by District' in a.text:
                    ran = True
                    continue
                #If you have passed 'Allocation Summary by District' start to save the category titles and links
                if ran:
                    if a['href'].startswith('http'):
                        urls.append(a['href'])
                    else:
                        urls.append(url_prefix + a['href'])
                    categories.append(a.text)
        except:
            continue
    
    #Formatting the titles
    for i, category_title in enumerate(categories):
        categories[i] = re.sub("\\r|\\t|\\n","",category_title)
    
    #List of dictionaries with allocation titles and galaxy listing
    categories_list = []

    #Add the galaxy listings for every allocation title
    for i, url in enumerate(urls):
        driver.get(url)
        funding_titles = driver.execute_script(script)
        res = requests.get(url)
 
        # Initialize the object with the document
        soup = BeautifulSoup(res.content, "html.parser")

        # Get the whole body tag
        tag = soup.body
        body = ""
        # Print each string recursively
        for string in tag.strings:
            body = body + "\n\n" + string
            
            
        categories_list.append({"Category": categories[i], "Galaxy Titles": funding_titles, "Body": body})
    
    return categories_list

# %%
allocationCategories2021 = getAllocationCategories(2021, driver)
allocationCategories2021
# Out:
# [{'Category': 'Fair Student Funding Memorandum', 'Galaxy Titles': []},
#  {'Category': 'Arts Supplemental Funding through Fair Student Funding',
#   'Galaxy Titles': ['TL Fair Student Funding', 'TL Fair Student Funding HS']},
#  {'Category': 'Career and Technical Education Supplement',
#   'Galaxy Titles': ['TL STEAM HS', 'TL CTE Programs HS']},
#  {'Category': 'ELA and Math Supplemental Support Services',
#   'Galaxy Titles': ['TL ELA/Math Student Support',
#    'Title IV Well Rounded ELA Math Support']},
#  {'Category': 'Contract for Excellence',
#   'Galaxy Titles': ['Contract for Excellence FY 09 HS',
#    'TL CB School Staff',
#    'Contract for Excellence FY 09']},
#  {'Category': 'Collective Bargaining for School Based Staff',
#   'Galaxy Titles': ['TL CB School Staff CW',
#    'TL CB School Staff D79',
#    'TL CB School Staff']},
#  {'Category': 'Summer In the City',
#   'Galaxy Titles': ['TL RS Student Summer in the City Services',
#    'ESY Student Summer in the City Services RS']},
#  {'Category': 'Title I School Allocations',
#   'Galaxy Titles': ['Title I TA Carry Over',
#    'Title I SWP',
#    'Title I 1003a TSI/CSI PS',
#    'Title I STH Non Title I Schools Carry Over',
#    'Title I 1003a TSI/CSI OTPS',
#    'Title I Targeted Assistance',
#    'Title I CSI Participatory Budget',
#    'High Need Support for Title I',
#    'Title I STH Carry Over',
#    'Title I STH',
#    'Title I STH for Non Title I Schools',
#    'Title I SWP Parent and Family Engagement',
#    'High Need Support for Title I STH',
#    'Title I SWP Carry Over',
#    'Title I TA Parent and Family Engagement']},
#  {'Category': 'Parent Coordinator Allocation',
#   'Galaxy Titles': ['TL Parent Coordinator HS',
#    'TL Parent Coordinator OTPS CW',
#    'TL Parent Coordinator HS – Flexible',
#    'TL Parent Coordinator CW',
#    'TL Parent Coordinator OTPS HS',
#    'TL Parent Coordinator OTPS',
#    'TL Parent Coordinator',
#    'TL Parent Coordinator HS - Contracted',
#    'TL Parent Coordinator - Contracted']},
#  {'Category': 'New       York State Textbook Law (NYSTL), Library, Hardware and Computer Software       (NYSSL) Funds',
#   'Galaxy Titles': ['TL NYSTL Library Books HS',
#    '',
#    'TL NYSTL Software HS',
#    'TL NYSTL Textbooks CW',
#    'TL NYSTL Hardware',
#    '                        NYCDOE Division of Finance Website Navigation',
#    'TL NYSTL Hardware HS',
#    'TL NYSTL Library Books CW',
#    'TL NYSTL Software',
#    'TL NYSTL Textbooks HS',
#    'TL NYSTL Library Books',
#    'TL NYSTL Textbooks',
#    ' ',
#    'TL NYSTL Hardware CW',
#    'TL NYSTL Software CW']},
#  {'Category': 'Section 504 Paraprofessional',
#   'Galaxy Titles': ['TL Section 504']},
#  {'Category': 'Individualized Education Program (IEP)/Intervention Teacher Allocation',
#   'Galaxy Titles': ['TL RS IEP TEACHER', 'TL RS IEP TEACHER HS']},
#  {'Category': 'Individualized Education Program (IEP) Paraprofessional Allocation',
#   'Galaxy Titles': ['TL RS IEP Para',
#    'IDEA RS IEP Para',
#    'TL CFES Open Schools Paras']},
#  {'Category': 'Mandated Related Services - (Speech, Counseling, OT/PT)',
#   'Galaxy Titles': ['TL RS Mandated Counseling Shared',
#    'TL RS Mandated Speech Shared',
#    'TL RS Occupational Therapist PS Shared',
#    'TL RS Physical Therapist PS Shared']},
#  {'Category': 'Adapted Physical Education',
#   'Galaxy Titles': ['TL RS APE Teacher Shared']},
#  {'Category': 'Specialized Programs - (ASD, BSE, ACES, Access)',
#   'Galaxy Titles': ['TL Summer in the City ASD',
#    'TL SE Specialized Program ICT Literacy',
#    'TL SE Specialized Program ACES',
#    'TL SE Specialized Program Access',
#    'TL SE Specialized Program BSE',
#    'TL SE Specialized Programs C4E ASD',
#    'TL SE Specialized Programs ASD']},
#  {'Category': 'Supports for Citywide Special Education',
#   'Galaxy Titles': ['TL Vision and Hearing Coverage',
#    'TL Part Time Inclusion']},
#  {'Category': 'Continuous Improvement Programs',
#   'Galaxy Titles': ['TL CB School Staff',
#    'TL Continuous Improvement Receivership',
#    'TL Continuous Improvement',
#    'TL Continuous Improvement HS',
#    'TL Continuous Improvement Receivership HS']},
#  {'Category': 'Title IV Programs',
#   'Galaxy Titles': ['Title IV ED Tech',
#    'Rollover Title IV Community Coordinator',
#    'Title IV Community Coordinator',
#    'Title IV Community Coordinator allocation',
#    'Title IV ED Tech Teams',
#    'Title IV Community Schools']},
#  {'Category': 'OTPS for New Schools',
#   'Galaxy Titles': ['TL OTPS New Schools', 'TL OTPS New Schools HS']},
#  {'Category': 'Pre-K and 3-K for All Programs in District Schools',
#   'Galaxy Titles': ['Contract for Excellence FY 09 Pre-K',
#    '4K for ALL',
#    '3K SCIS Classes',
#    'RS Pre-K Special Classes',
#    'Pre-K Special Classes',
#    '3-K for All',
#    '4-K for All ',
#    'Pre-K SCIS Classes']},
#  {'Category': 'Pre-K and 3-K for All in Pre-K Center Programs',
#   'Galaxy Titles': ['Pre-K Medicaid Speech Providers',
#    '4-K Pre-K Center',
#    '3-K Pre-K Center',
#    'Pre-K Special Ed Classes',
#    'RS Pre-K Special Classes',
#    'Pre-K SCIS Classes']},
#  {'Category': 'Robin Hood Libraries',
#   'Galaxy Titles': ['TL Robin Hood Libraries']},
#  {'Category': 'School Support Supplement',
#   'Galaxy Titles': ['School Support Supplement']},
#  {'Category': 'Title IIA Supplement', 'Galaxy Titles': []},
#  {'Category': 'District 75 Special Education Citywide Programs',
#   'Galaxy Titles': ['TL RS ESL CW',
#    'TL RS Therapist OTPS CW',
#    'TL Supplemental Instructional Support CW',
#    'TL COACH CW',
#    'TL RS Related Services CW',
#    'TL Project Arts CW',
#    'TL RS OT CW',
#    'TL Supplemental Instructional Services CW',
#    'TL RS IEP Para CW',
#    'TL RS Pre-K Related Services CW',
#    'TL RS BUS PARAS CW',
#    'TL RS Attendance CW',
#    'TL Specialized Equipment CW',
#    'TL Home and Hospital',
#    'TL Travel Training CW and',
#    'IDEA RS IEP Para CW',
#    'TL RS Pre-K Related Services',
#    'TL RS Speech CW',
#    'TL RS PT CW',
#    'TL TRAVELTRAINING CW',
#    'TL RS Counseling CW',
#    'TL Home & Hospitals',
#    'Tax Levy Pre-K Program Support',
#    'TL Pre-K Program Support CW',
#    'TL Instructional Programs CW',
#    'TL BMS CW']},
#  {'Category': 'District 79 Alternative Programs',
#   'Galaxy Titles': ['TL LYFE',
#    'TL Close To Home',
#    'TL STEP 79',
#    'TL HS Equivalency',
#    'TL Instructional Programs Adult ED HS D79',
#    'TL ReStart D79',
#    'TL CTE Co-op Course D79',
#    'TL Instructional Program HS YABC',
#    'TL 80 80 Rikers D79',
#    'TL Instructional Programs HS D79']},
#  {'Category': 'School Based IEP Team Staff',
#   'Galaxy Titles': ['(TL SBST Shared, TL SBST Shared D79)',
#    'TL SBST Shared, TL SBST Shared D79, IDEA SBST Shared and IDEA SBST Shared D79',
#    'TL SBST Shared',
#    '(IDEA SBST Shared, IDEA SBST Shared D79)',
#    'TL SBST Shared D79',
#    'IDEA SBST Shared D79',
#    'IDEA SBST Shared']},
#  {'Category': 'Pre-K Family Worker Allocation', 'Galaxy Titles': []},
#  {'Category': 'Title III Limited English Proficient (LEP) Program',
#   'Galaxy Titles': ['Title III LEP CW', 'Title III LEP']},
#  {'Category': 'Salary Subsidy for Excess Staff Hired to Permanent Assignments',
#   'Galaxy Titles': ['TL School Incentive (D79/D97) 2021 C1',
#    'TL Permanent Placement']},
#  {'Category': 'AIDP Attendance Social Worker Community Schools',
#   'Galaxy Titles': ['AIDP Community School Social Workers']},
#  {'Category': 'Deficit Rollover',
#   'Galaxy Titles': ['TL Instructional Programs',
#    'TL Instructional Programs HS',
#    'TL Fair Student Funding',
#    'TL Fair Student Funding HS']},
#  {'Category': 'Physical and Health Education Initiative',
#   'Galaxy Titles': ['TL Physical Education Initiative - Cohort 1, TL Physical Education Initiative - Cohort 2, TL Physical Education Initiative - Cohort 3',
#    'TL HEW School Wellness Council (CW)',
#    'TL CHAMPS (CW)']},
#  {'Category': 'Arts Funding Initiatives',
#   'Galaxy Titles': ['TL Broadway Junior Arts Supplement, TL Broadway Junior Arts Supplement CW, TL Broadway Junior Arts Supplement OTPS, TL Broadway Junior Arts Supplement OTPS CW',
#    'TL Arts Studio, TL Arts Studio HS, and TL Arts Studio CW',
#    'TL High School Screened Arts Program Supplement',
#    'TL ELL/Special Needs Partner Arts Project OTPS, TL ELL/Special Needs Partner Arts Project OTPS HS or TL ELL/Special Needs Partner Arts Project OTPS CW –',
#    'TL High School Screened Arts Program',
#    'TL Parent and Arts Partner Program OTPS CW',
#    'TL HS Arts Teachers Continuation',
#    'TL Parent and Arts Partner Program OTPS, TL Parent and Arts Partner Program OTPS HS']},
#  {'Category': 'Safe and Supportive Opportunity Program Expanded (SSOPE)',
#   'Galaxy Titles': ['TL SAFE & SUPPORTIVE OPPORTUNITY']},
#  {'Category': 'School COVID-19 Planning Supplement',
#   'Galaxy Titles': ['TL School COVID Planning Supplement D79',
#    'TL School COVID Planning Supplement CW',
#    'TL School COVID Planning Supplement']},
#  {'Category': 'Centrally Funded Excess Staff', 'Galaxy Titles': []},
#  {'Category': 'Guidance Counselors in High Need Schools',
#   'Galaxy Titles': ['TL Guidance Support High Need',
#    'TL Guidance Support High Need HS']},
#  {'Category': 'Substance Abuse Violence Prevention',
#   'Galaxy Titles': ['OASAS SUB ABUSE, TL SAPIS or OASAS LEGISLATIVE INITIATIVE']},
#  {'Category': 'School Social Workers in High-Need Schools',
#   'Galaxy Titles': ['TL Social Worker Support High Need']},
#  {'Category': 'Attendance Improvement/Dropout Prevention (AIDP) and Tax Levy (TL) Attendance Teachers',
#   'Galaxy Titles': ['AIDP Attendance Shared', 'TL Attendance Shared']},
#  {'Category': 'AIDP Students in Temporary Housing (STH)',
#   'Galaxy Titles': ['AIDP STH School and Site Based Shared']},
#  {'Category': 'Bridging the Gap School Social Workers', 'Galaxy Titles': []},
#  {'Category': 'Success Via Apprenticeship (SVA)',
#   'Galaxy Titles': ['TL SVA HS']},
#  {'Category': 'Alternate Learning Centers',
#   'Galaxy Titles': ['TL BOROUGH SUSPENSION CENTER']},
#  {'Category': 'Smart Schools Bond Act',
#   'Galaxy Titles': ['Smart Schools Bond Act']},
#  {'Category': 'Students Attending Institutional Facilities',
#   'Galaxy Titles': ['Title I Neglected D79 and Title I Delinquent D79']},
#  {'Category': 'City Council Member Items',
#   'Galaxy Titles': ['TL City Council Member Items',
#    'TL City Council Member Items Vendors']},
#  {'Category': 'Translation and Interpretation Services',
#   'Galaxy Titles': ['Title I SWP Translation Services',
#    'Title I Targeted Assistance Translation Services',
#    'TL Translation Services',
#    'TL Translation Services CW',
#    'Title III Translation Services']},
#  {'Category': 'Computer Maintenance',
#   'Galaxy Titles': ['TL Computer Maintenance CW',
#    'TL Computer Maintenance',
#    'TL Computer Maintenance HS']},
#  {'Category': 'Early Childhood Learning Bridges Program', 'Galaxy Titles': []},
#  {'Category': 'Law Enforcement Academy',
#   'Galaxy Titles': ['TL Justice Center Law Enforcement HS']},
#  {'Category': 'Psychologist in Training',
#   'Galaxy Titles': ['TL SBST PITs Shared']},
#  {'Category': 'School COVID-19 Reopening Staffing Supplement',
#   'Galaxy Titles': ['TL COVID Teacher Support',
#    'TL COVID Teacher Support CW',
#    'TL CRRSA COVID Teacher Support D79',
#    'TL CRRSA COVID Teacher Support CW',
#    'TL COVID Teacher Support D79',
#    'TL CRRSA COVID Teacher Support']},
#  {'Category': 'Equity & Excellence: Advanced Placement for All',
#   'Galaxy Titles': ['TL E&E Advanced Placement for All HS',
#    'TL E&E AP for All PSPD HS',
#    'TL E&E AP for All Support HS']},
#  {'Category': 'UFT Union Officers, District Representatives and Functional Chapter Leaders',
#   'Galaxy Titles': ['TL UFT Officers – Reps and Chapt Leaders CW',
#    'TL UFT Officers – Reps and Chapt Leaders',
#    'TL UFT Officers – Reps and Chapt Leaders HS']},
#  {'Category': 'Junior Reserve Officers Training Corps (JROTC)',
#   'Galaxy Titles': ['TL ROTC']},
#  {'Category': 'Carl D. Perkins Career and Technical Education (Perkins V)',
#   'Galaxy Titles': ['Perkins V']},
#  {'Category': 'Teacher and School Leader Grant',
#   'Galaxy Titles': ['TSL Grant']},
#  {'Category': 'Identity-Based Student Clubs',
#   'Galaxy Titles': ['TL Student Club Initiative OTPS',
#    'TL Student Club Advisor PS (CW)']},
#  {'Category': 'Student Mentoring Programs',
#   'Galaxy Titles': ['TL YMI Eagle Academy',
#    'TL NYC MENTORING OTPS',
#    'TL YMI Peer to Peer',
#    'TL YMI NINE SQUARED',
#    'TL NYC MENTORING PS']},
#  {'Category': 'College and Career Readiness for MLLs/ELLs Initiative',
#   'Galaxy Titles': ['TL ELL Initiative College Ready']},
#  {'Category': 'Long Term Absence',
#   'Galaxy Titles': ['TL ASA HH', 'TL Long Term Absence']},
#  {'Category': 'Instructional Leadership Framework',
#   'Galaxy Titles': ['TL Instructional Leadership Framework (CW)']},
#  {'Category': 'Summer in the City 12-Month Assistant Principal',
#   'Galaxy Titles': ['TL 12-Month AP or TL 12-Month AP HS']},
#  {'Category': 'Periodic Assessment Administration',
#   'Galaxy Titles': ['TL Periodic Assessment (CW)']},
#  {'Category': 'Sustainability Initiatives',
#   'Galaxy Titles': ['Private Grant 99 Energy Demand',
#    'PLANYC DCAS DOE Energy Challenge School Awards']},
#  {'Category': 'Attendance Improvement/Dropout Prevention (AIDP) Discretionary Allocation',
#   'Galaxy Titles': ['AIDP']},
#  {'Category': 'College Access for All Initiative',
#   'Galaxy Titles': ['TL E&E College Access 4 ALL CW',
#    'TL E&E College Access 4 ALL HS']},
#  {'Category': 'Educator Pipeline Programs',
#   'Galaxy Titles': ['TL YMI Men Teach', 'TL Urban Teacher Residency (HS)']},
#  {'Category': 'Safe Schools Initiative', 'Galaxy Titles': ['TL SAFE SCHOOL']},
#  {'Category': 'CTE Expansion Initiatives', 'Galaxy Titles': ['TL CTE WBL HS']},
#  {'Category': 'Specialized High School Admissions Testing',
#   'Galaxy Titles': ['TL Specialized Admissions HS.']},
#  {'Category': 'Title III Immigrant Programs',
#   'Galaxy Titles': ['Title III Immigrant', 'Title III Immigrant Carryover']},
#  {'Category': 'Implicit Bias Awareness Workshops',
#   'Galaxy Titles': ['TL Implicit Bias Awareness or TL Implicit Bias Awareness CW',
#    'TL Implicit Bias CCER or TL Implicit Bias CCER CW']},
#  {'Category': 'Transcript Maintenance',
#   'Galaxy Titles': ['TL Host Schools HS']},
#  {'Category': 'School COVID-19 Register Loss Mid-Year Adjustment Restoration',
#   'Galaxy Titles': ['TL CRRSA COVID MY Register Loss Restoration',
#    'Register Loss',
#    'TL CRRSA COVID MYA Register Loss Restoration',
#    'TL COVID MY Register Loss Restoration',
#    'TL CRRSA COVID MYA Register Loss Restoration HS',
#    'Restoration',
#    'TL CRRSA COVID MY Register Loss Restoration HS',
#    'TL COVID MY Register Loss Restoration HS',
#    'TL CRRSA COVID MY']},
#  {'Category': 'Virtual Content Specialist Salary Differential Allocation',
#   'Galaxy Titles': ['TL Virtual Content Specialist (CW)']},
#  {'Category': 'Title IV Summer Rising Re-Opening Planning',
#   'Galaxy Titles': ['Title IV Summer Rising Reopening Planning']}]

# %%
allocationCategories2020 = getAllocationCategories(2020, driver)
allocationCategories2020
# Out:
# [{'Category': 'Fair Student Funding Memorandum', 'Galaxy Titles': []},
#  {'Category': 'Deferred Program Planning Initiative (DPPI) ',
#   'Galaxy Titles': ['TL Deferred Program Planning Initiative D79',
#    'TL Deferred Program Planning Initiative',
#    'TL Deferred Program Planning Initiative (HS/CW/D79)']},
#  {'Category': 'Arts Supplemental Funding thru Fair Student Funding',
#   'Galaxy Titles': ['TL Fair Student Funding', 'TL Fair Student Funding HS']},
#  {'Category': 'ELA and Math Supplemental Support Services',
#   'Galaxy Titles': ['TL ELA/Math Student Support']},
#  {'Category': 'Contracts for Excellence (C4E) Discretionary Allocations to Schools',
#   'Galaxy Titles': ['Contract for Excellence FY09 HS',
#    'Contract for Excellence FY09']},
#  {'Category': 'Collective Bargaining for School Based Staff',
#   'Galaxy Titles': ['TL CB School Staff D88']},
#  {'Category': 'Summer In the City', 'Galaxy Titles': []},
#  {'Category': 'Title I School Allocations',
#   'Galaxy Titles': ['TL CB School Staff']},
#  {'Category': 'Parent Coordinator Allocation',
#   'Galaxy Titles': ['TL Parent Coordinator HS',
#    'TL Parent Coordinator OTPS CW',
#    'TL Parent Coordinator HS – Flexible',
#    'TL Parent Coordinator CW',
#    'TL Parent Coordinator OTPS HS',
#    'TL Parent Coordinator OTPS',
#    'TL Parent Coordinator',
#    'TL Parent Coordinator HS - Contracted',
#    'TL Parent Coordinator - Contracted']},
#  {'Category': 'New York State Textbook Law (NYSTL), Library, Hardware and Computer Software (NYSSL) Funds',
#   'Galaxy Titles': ['TL NYSTL Library Books HS',
#    'TL NYSTL Software HS',
#    'TL NYSTL Textbooks CW',
#    'TL NYSTL Hardware',
#    'TL NYSTL Hardware HS',
#    'TL NYSTL Library Books CW',
#    'TL NYSTL Software',
#    'TL NYSTL Textbooks HS',
#    'TL NYSTL Library Books',
#    'TL NYSTL Textbooks',
#    'TL NYSTL Hardware CW',
#    'TL NYSTL Software CW']},
#  {'Category': 'Career and Technical Education Supplement',
#   'Galaxy Titles': ['TL CTE Programs HS']},
#  {'Category': 'Individualized Education Program (IEP)/Intervention Teacher Allocation',
#   'Galaxy Titles': ['TL RS IEP TEACHER', 'TL RS IEP TEACHER HS.']},
#  {'Category': 'Individualized Education Program (IEP) Paraprofessional Allocation',
#   'Galaxy Titles': ['TL RS IEP Para',
#    'IDEA RS IEP Para',
#    'TL CFES Open Schools Paras']},
#  {'Category': 'Mandated Related Services - (Speech, Counseling, OT/PT)',
#   'Galaxy Titles': []},
#  {'Category': 'Adapted Physical Education',
#   'Galaxy Titles': ['TL RS APE Teacher Shared']},
#  {'Category': 'Specialized Programs - (ASD, BSE, ACES, Access)',
#   'Galaxy Titles': ['TL Summer in the City ASD',
#    'TL SE Specialized Program ICT Literacy',
#    'TL SE Specialized Program ACES',
#    'TL SE Specialized Program Access',
#    'TL SE Specialized Program BSE',
#    'TL SE Specialized Programs C4E ASD',
#    'TL SE Specialized Programs ASD',
#    'TL SE Specialized Program Mixed Group']},
#  {'Category': 'Supports for Citywide Special Education',
#   'Galaxy Titles': ['TL Vision and Hearing Coverage',
#    'TL Part Time Inclusion']},
#  {'Category': 'Continuous Improvement Programs',
#   'Galaxy Titles': ['TL CB School Staff']},
#  {'Category': 'Title IV Programs',
#   'Galaxy Titles': ['Rollover Title IV Community Coordinator',
#    'Title IV ED Tech.',
#    'Title IV Community Coordinator',
#    'Title IV Community Schools',
#    'Title IV Well Rounded']},
#  {'Category': 'OTPS for New Schools',
#   'Galaxy Titles': ['TL OTPS New Schools', 'TL OTPS New Schools HS']},
#  {'Category': 'Pre-K and 3-K for All Programs in District Schools',
#   'Galaxy Titles': []},
#  {'Category': 'Pre-K and 3-K for All in Pre-K Center Programs',
#   'Galaxy Titles': ['Pre-K Medicaid Speech Providers',
#    '4-K Pre-K Center',
#    'RS Pre-K Special Classes  ',
#    '3-K Pre-K Center',
#    'Pre-K SCIS Classes']},
#  {'Category': 'Robin Hood Libraries',
#   'Galaxy Titles': ['TL Robin Hood Libraries']},
#  {'Category': 'School Support Supplement',
#   'Galaxy Titles': ['School Support Supplement']},
#  {'Category': 'Title IIA Supplement',
#   'Galaxy Titles': ['Title IIA Supplemental', 'School Support Supplement']},
#  {'Category': 'District 75 Special Education Citywide Programs',
#   'Galaxy Titles': ['TL RS ESL CW',
#    'TL RS Therapist OTPS CW',
#    'TL Supplemental Instructional Support CW',
#    'TL COACH CW',
#    'TL RS Related Services CW',
#    'TL Project Arts CW',
#    'TL RS OT CW',
#    'TL RS IEP Para CW',
#    'TL RS Pre-K Related Services CW',
#    'TL RS BUS PARAS CW',
#    'TL RS Attendance CW',
#    'TL Specialized Equipment CW',
#    'TL Home and Hospital',
#    'IDEA RS IEP Para CW',
#    'TL RS Speech CW',
#    'TL RS PT CW',
#    'TL TRAVELTRAINING CW',
#    'TL RS Counseling CW',
#    'TL Pre-K Program Support CW',
#    'TL Instructional Programs CW',
#    'TL BMS CW']},
#  {'Category': 'District 79 Alternative Programs',
#   'Galaxy Titles': ['TL HS Equivalency',
#    'TL ReStart D79',
#    'TL Close To Home']},
#  {'Category': 'Screened Arts Initiatives',
#   'Galaxy Titles': ['TL HS Screen Arts Designation',
#    'TL HS Screened Arts Designation Planning',
#    'TL High School Screened Arts Program Supplement',
#    'TL High School Screened Arts Program, TL Middle School Screened Arts Program']},
#  {'Category': 'Special Education Transitional Supplement',
#   'Galaxy Titles': []},
#  {'Category': 'Title III Limited English Proficient (LEP) Program',
#   'Galaxy Titles': ['Title III LEP CW', 'Title III LEP']},
#  {'Category': 'Salary Subsidy for Excess Staff Hired to Permanent Assignments',
#   'Galaxy Titles': ['TL School Incentive (D79/D97) 2021 C1',
#    'TL Salary Subsidy 2020']},
#  {'Category': 'Summer Title I School Improvement Grants',
#   'Galaxy Titles': ['Title I 1003(a) Summer']},
#  {'Category': 'Deficit Rollover',
#   'Galaxy Titles': ['TL Fair Student Funding']},
#  {'Category': 'Physical and Health Education Initiative',
#   'Galaxy Titles': ['TL Physical Education Initiative - Cohort 1, TL Physical Education Initiative - Cohort 2, TL Physical Education Initiative - Cohort 3']},
#  {'Category': 'Equity & Excellence:  Advanced Placement for All',
#   'Galaxy Titles': ['for All Support HS',
#    'TL E&E AP for',
#    'TL E&E AP for All Support HS',
#    'TL E&E Advanced Placement for All HS',
#    'TL E&E AP',
#    'All PSPD HS']},
#  {'Category': 'Success Via Apprenticeship (SVA) Program',
#   'Galaxy Titles': ['TL SVA HS', 'VATEA SVA']},
#  {'Category': 'Pre-K for All: Additional Paraprofessional Support',
#   'Galaxy Titles': ['• 4K Para Support']},
#  {'Category': 'Centrally Funded Excess Staff', 'Galaxy Titles': []},
#  {'Category': 'Bronx Collaborative Schools Model',
#   'Galaxy Titles': ['Title IV Collaborative Schools Micro-Grants']},
#  {'Category': 'School Based IEP Team Staff',
#   'Galaxy Titles': ['(TL SBST Shared, TL SBST Shared D79)',
#    'TL SBST Shared, TL SBST Shared D79, IDEA SBST Shared and IDEA SBST Shared D79',
#    'TL SBST Shared',
#    '(IDEA SBST Shared, IDEA SBST Shared D79)',
#    'TL SBST Shared D79',
#    'IDEA SBST Shared',
#    'IDEA SBST Shared D79',
#    '(TL SBST Shared, TL SBST Shared D79):']},
#  {'Category': 'Pre-K Family Worker Allocation',
#   'Galaxy Titles': ['4K for All']},
#  {'Category': 'Student Mentoring Programs',
#   'Galaxy Titles': ['FUNDS PUB SCHL – NYC MENTORING PROG',
#    'TL YMI Eagle Academy',
#    'TL NYC MENTORING OTPS',
#    'TL YMI NINE SQUARED',
#    'L NCSI After-School Tutoring or TL NCSI After-School Tutoring CW',
#    'TL YMI Peer to Peer (HS)',
#    'TL NYC MENTORING PS']},
#  {'Category': 'Students Attending Institutional Facilities',
#   'Galaxy Titles': ['Title I Neglected D79', 'Title I Delinquent D79']},
#  {'Category': 'Alternate Learning Centers',
#   'Galaxy Titles': ['TL BOROUGH SUSPENSION CENTER']},
#  {'Category': 'Safe and Supportive Opportunity Program Expanded (SSOPE)',
#   'Galaxy Titles': ['TL SAFE & SUPPORTIVE OPPORTUNITY']},
#  {'Category': 'Sustainability Initiatives',
#   'Galaxy Titles': ['PLANYC DCAS DOE Energy Challenge School Awards',
#    'Private Grant 99 Energy Demand',
#    'Private Grant 99 Energy Demand (02999)',
#    'IC Rev DSNY Zero Waste School Awards']},
#  {'Category': 'Identity-Based Student Clubs',
#   'Galaxy Titles': ['TL STUDENT CLUB INITIATIVE OTPS (CW)',
#    'TL STUDENT CLUB ADVISOR PS (CW)']},
#  {'Category': 'Psychologist-In-Training',
#   'Galaxy Titles': ['TL SBST PITs Shared']},
#  {'Category': 'Section 504 Paraprofessional',
#   'Galaxy Titles': ['TL Section 504']},
#  {'Category': 'Bridging the Gap School Social Workers',
#   'Galaxy Titles': ['TL Bridging the Gap']},
#  {'Category': 'Guidance Counselors in High-Need Schools',
#   'Galaxy Titles': ['TL Guidance Support High Need',
#    'TL Guidance Support High Need HS',
#    'TL Guidance Support HS',
#    'TL Guidance Support']},
#  {'Category': 'City Council Member Items ',
#   'Galaxy Titles': ['TL City Council Member Items',
#    'TL City Council Member Items Vendors']},
#  {'Category': 'Substance Abuse Violence Prevention',
#   'Galaxy Titles': ['OASAS SUB ABUSE, TL SAPIS or OASAS LEGISLATIVE INITIATIVE']},
#  {'Category': 'Computer Maintenance',
#   'Galaxy Titles': ['TL Computer Maintenance', 'TL Computer Maintenance HS']},
#  {'Category': 'Measures of Student Learning',
#   'Galaxy Titles': ['TL MOSL or TL MOSL CW']},
#  {'Category': 'Arts Supplemental Funding Initiatives',
#   'Galaxy Titles': ['TL Arts Studio CW.',
#    'TL Broadway Junior Arts Supplement, TL Broadway Junior Arts Supplement HS, and TL Broadway Junior Arts Supplement CW, TL Broadway Junior Arts Supplement OTPS, TL Broadway Junior Arts Supplement OTPS HS, TL Broadway Junior Arts Supplement OTPS CW',
#    'TL Part Time Arts Support',
#    'TL SING Arts',
#    'TL Arts Studio, TL Arts Studio HS,',
#    'TL Part Time Arts HS']},
#  {'Category': 'Translation and Interpretation Services',
#   'Galaxy Titles': ['TL Translation Services or TL Translation Services CW.',
#    'Title III Translation Services.',
#    'Title I SWP Translation Services',
#    'Title I Targeted Assistance Translation Services']},
#  {'Category': 'Equity and Excellence: College Access for All Initiative',
#   'Galaxy Titles': ['TL E&E LINCT Program HS',
#    'TL E&E MS College Access PS, TL E&E MS College Access CW PS or TL E&E MS College Access OTPS and TL E&E MS College Access CW OTPS.']},
#  {'Category': 'Arts Partnership Grants',
#   'Galaxy Titles': ['TL ELL/Special Needs Partner Arts Project PS, TL ELL/Special Needs Partner Arts Project PS HS',
#    'TL Parent and Arts Partner Program OTPS, TL Parent and Arts Partner Program OTPS HS or TL Parent and Arts Partner Program OTPS CW –',
#    'TL Parent and Arts Partner Program PS, TL Parent and Arts Partner Program PS HS or TL Parent and Arts Partner Program PS CW –',
#    'TL ELL/Special Needs Partner Arts Project OTPS, TL ELL/Special Needs Partner Arts Project OTPS HS',
#    'TL ELL/Special Needs Partner Arts Project OTPS CW']},
#  {'Category': 'Law Enforcement Academy',
#   'Galaxy Titles': ['TL Justice Center Law Enforcement HS']},
#  {'Category': 'School Social Workers in High-Need Schools',
#   'Galaxy Titles': ['TL Social Worker Support High Need.']},
#  {'Category': 'CTE Expansion Initiatives',
#   'Galaxy Titles': ['TL CTE Middle School Exploration',
#    'TL CTE WBL HS',
#    'VATEA WBL HS']},
#  {'Category': 'Teacher Leadership Programs Allocation ',
#   'Galaxy Titles': ['TL TLP Teacher Development, (HS) or (CW)',
#    'TL Teacher Career Pathways – Subsidy Allocation',
#    'Title I SWP Teacher Leadership']},
#  {'Category': 'Educator Pipeline Programs ',
#   'Galaxy Titles': ['TL YMI Men Teach',
#    'TL New Principal Support (HS/CW)',
#    'TL LEAP (HS/CW).',
#    'TL Urban Teacher Residency (HS)']},
#  {'Category': 'Attendance Improvement/Dropout Prevention (AIDP) and Tax Levy (TL)   Attendance Teachers',
#   'Galaxy Titles': ['AIDP Attendance Shared', 'TL Attendance Shared']},
#  {'Category': 'Safety, Youth Development and School Climate Initiatives',
#   'Galaxy Titles': ['TL Restorative Justice',
#    'TL Restorative Justice Mentor',
#    'TL SAFE SCHOOL']},
#  {'Category': 'Transcript Maintenance',
#   'Galaxy Titles': ['TL Host School HS']},
#  {'Category': 'NYC Pre-K & 3-K Thrive',
#   'Galaxy Titles': ['Pre-K and 3K Thrive.']},
#  {'Category': 'Interschool Collaboration Funding',
#   'Galaxy Titles': ['TL E&E District Charter Collaborative',
#    'TL E&E Campus District Charter Partnerships']},
#  {'Category': 'Vocational and Technical Education Allocation (VTEA)',
#   'Galaxy Titles': ['VATEA', 'VATEA CTE Driver HS']},
#  {'Category': 'Junior Reserve Officers Training Corps (JROTC)',
#   'Galaxy Titles': ['TL ROTC']},
#  {'Category': 'AIDP Students in Temporary Housing (STH)',
#   'Galaxy Titles': ['AIDP STH School and Site Based Shared and AIDP Family Worker Per Session']},
#  {'Category': 'Specialized High School Admissions Testing',
#   'Galaxy Titles': ['TL Specialized Admissions HS', 'TL SHSAT Test Prep']},
#  {'Category': 'Title III Immigrant Programs',
#   'Galaxy Titles': ['Title III Immigrant']},
#  {'Category': 'Middle School Quality Initiative',
#   'Galaxy Titles': ['TL MS Task Force']},
#  {'Category': 'Long Term Absence',
#   'Galaxy Titles': ['TL ASA HH', 'TL Long Term Absence']},
#  {'Category': 'College and Career Readiness for MLLs/ELLs Initiative',
#   'Galaxy Titles': ['TL ELL Initiative College Ready']},
#  {'Category': 'Attendance Improvement/Dropout Prevention (AIDP) Discretionary Allocation',
#   'Galaxy Titles': ['AIDP']},
#  {'Category': 'AIDP Attendance Social Worker Community Schools',
#   'Galaxy Titles': ['AIDP Community School Social Workers']},
#  {'Category': 'Instructional Leadership Framework',
#   'Galaxy Titles': ['TL Instructional Leadership Framework (CW)',
#    'TL Instructional Leadership Program Support']},
#  {'Category': 'Teacher and School Leader Grant',
#   'Galaxy Titles': ['TSL Grant', 'Rollover TSL Grant.']},
#  {'Category': 'Implicit Bias Awareness Workshops',
#   'Galaxy Titles': ['TL Implicit Bias CCER CW',
#    'TL Implicit Bias Awareness',
#    'TL Implicit Bias CCER',
#    'TL Implicit Bias Awareness CW']},
#  {'Category': 'OTPS Allocation for PSAL Program', 'Galaxy Titles': []},
#  {'Category': 'Equity and Excellence: Universal Literacy',
#   'Galaxy Titles': ['TL E&E Universal Literacy']},
#  {'Category': 'Social and Emotional Learning',
#   'Galaxy Titles': ['TL Social and Emotional Learning',
#    'TL Social and Emotional Learning HS']},
#  {'Category': 'UFT Union Officers, District Representatives and Functional Chapter Leaders',
#   'Galaxy Titles': ['TL UFT Officers – Reps and Chapt Leaders',
#    'TL UFT Officers – Reps and Chapt Leaders HS']},
#  {'Category': 'Summer in the City 12-Month Assistant Principal',
#   'Galaxy Titles': ['TL 12-Month AP or TL 12-Month AP HS']},
#  {'Category': 'Civics for All: Participatory Budgeting',
#   'Galaxy Titles': ['TL Civics for All (CW)']},
#  {'Category': 'Regents Distributed Scoring',
#   'Galaxy Titles': ['TL Regents Distributed Scoring', 'TL LOTE']},
#  {'Category': 'Gifted And Talented Programs',
#   'Galaxy Titles': ['TL Talented and Gifted']},
#  {'Category': 'Title I 1003a School Improvement Grant ',
#   'Galaxy Titles': ['            Title I 1003a TSI/CSI PS',
#    '            Title I 1003a TSI/CSI OTPS']},
#  {'Category': 'Smart Schools Bond Act',
#   'Galaxy Titles': ['Smart Schools Bond Act']},
#  {'Category': 'Learning and Practicing Tolerance',
#   'Galaxy Titles': ['TL Learning and Practicing Tolerance (HS)']},
#  {'Category': 'Equity and Excellence: Algebra for All',
#   'Galaxy Titles': ['TL E&E Algebra for All']},
#  {'Category': 'Diversity in Admissions Implementation',
#   'Galaxy Titles': ['TL Admissions Diversity']},
#  {'Category': 'TBA', 'Galaxy Titles': []},
#  {'Category': 'School Planning Support',
#   'Galaxy Titles': ['TL New School Planning']}]

# %%
allocationCategories2022 = getAllocationCategories(2022, driver)
allocationCategories2022
# Out:
# [{'Category': 'Arts Supplemental Funding through Fair Student Funding',
#   'Galaxy Titles': ['TL Fair Student Funding ', 'TL Fair Student Funding HS'],
#   'Body': "\n\n\n\n\n\n\n\n\n\n\n\n\n\nNYCDOE Division of Finance Website Navigation\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSCHOOL ALLOCATION MEMORANDUM NO. 02, FY 2022\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nDATE:  \n\n\n\n\nJune 18, 2021\n\n\n\n\n\n\n\nTO:\n\n\n\n\nExecutive Superintendents \n\n\r\n\t\t\t\t\t    \t\t        Community Superintendents \n\n\r\n\t\t\t\t\t     \t\t\tHigh School Superintendents \n\n\r\n \t\t\t\t\t     \t\t\tBorough/Citywide Office Teams \n\n\r\n \t\t\t\t\t     \t\t\tSchool Principals \n\n \n\n\n\n\n\n\n\nFROM:    \n\n\n\n\nLindsey Oates, Chief Financial Officer\n\n\n\n\n\n\n\nSUBJECT:    \n\n\n\n\nArts Supplemental Funding through Fair Student Funding\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nThis memorandum provides guidance on planning for arts programs using Fair Student Funding (FSF)\r\n and is intended to help schools effectively utilize resources and plan quality arts programming to meet NYSED arts instructional\r\n requirements for the upcoming school year.  Allocation amounts represented in this document are for advisory purposes only and\r\n have historically been provided to schools for informational purposes at their request.  Schools' FSF allocations reflect growth\r\n for increased salary costs due to collective bargaining agreements.  The change to the per capita amount for supplemental arts \r\nprogram in FY 2022 is a net increase from the FY 2021 per capita of $79.99 to $79.62. \n\n Please note that this money is already part \r\nof schools' FSF allocations.  It does not represent new funds.\n\n\n\n\n \n\n\n\n\nSchools can schedule their arts supplemental funding using \n\nTL Fair Student Funding \n\nand\r\n \n\nTL Fair Student Funding HS\n\n allocation categories.\r\n  When scheduling funds, schools should select the program description \n\nARTS SUPPLEMENT\n\n from the drop down list.  All expenditures for arts\r\n education should be noted as such in Galaxy so that we can accurately collect spending data on arts education for the annual \n\nArts in Schools Report\n\n.\n\n\n\n\nQuestions may be directed to the Office of Arts & Special Projects at\r\n\n\n\r\nArtsAndSpecialProjects@schools.nyc.gov\n\n. \r\n\r\n\n\nWith regards to the school consolidations that take effect in FY 2022, Arts Supplemental funds for the pertinent schools will be combined via the\r\n projected registers process.\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nDownload a copy of the School Allocation Memorandum No. 02, FY 2022\n\n\n\n\n\n\n\nAttachment:\n\n\n\n\nTable 1 - \n\nArts Supplemental Funding Summary\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nLO: ms\n\n\n\n\nC:    \n\n\n\n\nDr. Linda Chen \n\n\r\n\t\t\t\t\t     Michael Feliciano\n\n \n\n \r\n\t\t\t\t\t     Lawrence Pendergast\n\n \n\n\r\n\t\t\t\t\t     Trenton Price\n\n \n\n\r\n\t\t\t\t\t     Maria Palma\n\n \n\n\r\n\t\t\t\t\t     Lucius Young\n\n \n\n\r\n\t\t\t\t\t     Tanisha Oliver\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nNYCDOE Division of Finance Website Navigation\n\n\n\n\n\n\n\n\n"},
#  {'Category': 'Career and Technical Education Supplement',
#   'Galaxy Titles': ['TL CTE Programs HS',
#    'TL STEAM HS ',
#    'CRRSA E&E Early College'],
#   'Body': '\n\n\n\n\n\n\n\n\n\n\n\n\n\nNYCDOE Division of Finance Website Navigation\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSCHOOL ALLOCATION MEMORANDUM NO. 03, FY 2022\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nRevised January 14, 2022\n\n\n\n\n\n\n\nDATE:  \n\n\n\n\nJune 18, 2021\n\n\n\n\n\n\n\nTO:\n\n\n\n\nExecutive Superintendents \n\n\r\n\t\t\t\t\t    \t\t        Community Superintendents \n\n\r\n\t\t\t\t\t     \t\t\tHigh School Superintendents \n\n\r\n \t\t\t\t\t     \t\t\tBorough/Citywide Office Teams \n\n\r\n \t\t\t\t\t     \t\t\tSchool Principals \n\n \n\n\n\n\n\n\n\nFROM:    \n\n\n\n\nLindsey Oates, Chief Financial Officer\n\n\n\n\n\n\n\nSUBJECT:    \n\n\n\n\nCareer and Technical Education Supplement\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nThis memorandum funds Career and Technical Education (CTE) programs.  This allocation is\r\n based on pupil CTE credits in the 2020-2021 school year, primarily in non-CTE designated high schools, and also provides\r\n supplemental funding in CTE-designated high schools.  As a result of the impact of COVID-19 on the remote learning grading\r\n policy, NX marks have been included until final marks are made available. Funding will also support the STEAM program, which\r\n will provide shared CTE instruction across a predetermined group of CTE and non-CTE schools in Brooklyn.  This allocation will\r\n enable high schools to offer and expand high quality CTE programs, and provide for long-term sustainability.  \n\n \n\n\n\n\nAs a result of the impact of COVID-19, NX marks in CTE classes are considered to be earned pupil credits for the purposes \r\nof this SAM. Subsequent rounds of funding under this SAM will be modified as pupil credits are finalized. \n\n\n\n\nFunding for Academic HS:\n\n\n\n\nCTE programs in non-CTE designated schools have been selected based upon their commitment to, and continued development of,\r\n high quality CTE programs.  With an emphasis on the expansion and improvement of CTE programming, funds will now support the \r\nhigher cost to provide students and staff with the CTE experiences necessary to maintain a high quality CTE program.  Funding \r\nwill be allocated in a tiered structure that addresses significant factors in CTE programming, such as CTE class-size requirements,\r\n costs for equipment and consumable materials, industry training for teachers, student work experiences, and lab upgrades.  Schools \r\nreceiving these funds must dedicate these resources for the overall improvement and growth of CTE in their school. \n\n\n\n\nFunding for FSF Portfolio HS:\n\n\n\n\nSchools that receive FSF Specialized Academic or Specialized Audition Portfolio per pupil funding will receive a reduced CTE per \r\ncapita, given that these schools already receive incremental per pupil funding through the formula, but also bear additional incremental\r\n costs relative to other specialized schools without CTE programs. \n\n\n\n\nFunding for FSF CTE designated HS:\n\n\n\n\nCTE designated high schools receive resources in Fair Student Funding (FSF) based on the relative cost factors necessary to operate \r\ndifferent CTE programs of study, assuming standard CTE credits.  This allocation provides supplemental funding in CTE designated high \r\nschools where students are enrolled in intensive CTE program course sequences. \n\n\n\n\nFunding for the Brooklyn STEAM Center:\n\n\n\n\nThe Science, Technology, Engineering, Arts, and Math (S.T.E.A.M.) Center is a partnership between the DOE, Brooklyn Navy Yard (BNY), \r\nthe Brooklyn Historical Society and NY State.  The innovative hub model will offer 5 CTE Pathways across 8 area Brooklyn high schools.  \r\nThe model is intended to increase socioeconomic diversity, to improve student achievement, and to provide students with high quality, \r\nindustry aligned curriculum in addition to real-time access to industry partners with on-site work-based learning experiences at the Navy ...
#  {'Category': 'ELA and Math Supplemental Support Services',
#   'Galaxy Titles': ['TL ELA/Math Student Support',
#    'Title IV Well Rounded ELA Math Support'],
#   'Body': "\n\n\n\n\n\n\n\n\n\n\n\n\n\nNYCDOE Division of Finance Website Navigation\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSCHOOL ALLOCATION MEMORANDUM NO. 04, FY 2022\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nDATE:  \n\n\n\n\nJune 18, 2021\n\n\n\n\n\n\n\nTO:\n\n\n\n\nExecutive Superintendents \n\n\r\n\t\t\t\t\t    \t\t        Community Superintendents \n\n\r\n\t\t\t\t\t     \t\t\tHigh School Superintendents \n\n\r\n \t\t\t\t\t     \t\t\tBorough/Citywide Office Teams \n\n\r\n \t\t\t\t\t     \t\t\tSchool Principals \n\n \n\n\n\n\n\n\n\nFROM:    \n\n\n\n\nLindsey Oates, Chief Financial Officer\n\n\n\n\n\n\n\nSUBJECT:    \n\n\n\n\nELA and Math Supplemental Support Services\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nThis memorandum funds additional support for students, who are performing well below proficiency in English Language Arts (ELA) and Math, to improve their literacy and mathematics skills.\r\n\n\n\n\n\nFY 2022 Criteria:\n\n\n\n\nThe allocation is based on the following criteria:\n\n\n\n\n\n\n\nPerformance on the 2019 New York State exams is multiplied by the 2021-2022 projected register.  Academic performance is measured as follows:\n\n\n\n\n\n\n\nES/MS:\n\n The number and percentage of students who scored at Level 1 on state exams for grades 3-8 out of students who took the math exam; \r\n\t\tand the number and percentage of students who scored at Level 1 on state exams for grades 3-8 out of students who took the English exam;\n\n\n\n\nHS:\n\n Students in grades 9-12 who scored below 65 on all 2019 math Regents exam attempts (of those who sat for a January, June and/or August 2019 exam);\r\n\t\t and students in grades 9-12 who scored below 65 on all 2019 English Regents exam attempts (of those who sat for a January, June and/or August 2019 exam).\n\n\n\n\n\n\n\n2020-2021 Economic Need Index multiplied by the 2021-2022 projected register.\n\n\n\n\n\n\n\nTwo-thirds of the funds are being allocated on the basis of performance and one-third based on Economic Need Index indicators. This weighting is achieved by multiplying the schoolâ€™s estimated \r\nperformance count by a factor of 2. However, any school with performance or poverty registers that would have generated an allocation of less than $5,000 will not receive any tax levy funds.\r\n\n\n\n\n\nFor FY 2022 there will be a one-time infusion of Title IV Well Rounded funding added to the program so that schools can provide additional supports for students due to the challenges \r\nbrought on by the COVID-19 pandemic.  The Title IV portion of the funding is also allocated based on performance and Economic Need Index indicators, however, all schools will receive a base \r\nallocation of $1,500. Fringe benefits are required when scheduling Title IV funding. \r\n\n\n\n\n\nGuidelines for Supplemental Allocation:\n\n\n\n\nSchools receiving this allocation should use these funds to support the implementation of Academic Intervention Services.  The New York State Education Department (NYSED) issued this memo on \r\nSeptember 11, 2018 outlining a two-step method to assist in identifying students in grades 3-8 who are eligible for Academic Intervention Services (AIS).\r\n\n\n\n\n\nFunds should be used to implement your AIS plan as described in your 2021-2022 Comprehensive Education Plan (CEP). Funds can be spent on activities such as research-based intervention programs, \r\nprotocols and related assessment tools for use in the various targeted intervention tiers of service, Saturday academies, after-school sessions, computer and web-based programs aligned with Common \r\nCore Standards and a targeted, diagnostic-prescriptive model of intervention, as well as other types of support in accordance with the school's overall academic intervention services plan.\r\n\n\n\n\n\nSchools' FSF, Funds over Formula, allocations will be reduced up to the amount of the ELA/Math Supplemental Support Services allocation, capped at  ...
#  {'Category': 'Contract for Excellence',
#   'Galaxy Titles': ['Contract for Excellence FY 09',
#    ' Contract for Excellence FY 09 HS',
#    'TL CB School Staff'],
#   'Body': '\n\n\n\n\n\n\n\n\n\n\n\n\n\nNYCDOE Division of Finance Website Navigation\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSCHOOL ALLOCATION MEMORANDUM NO. 05, FY 2022\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nDATE:  \n\n\n\n\nJune 18, 2021\n\n\n\n\n\n\n\nTO:\n\n\n\n\nExecutive Superintendents \n\n\r\n\t\t\t\t\t    \t\t        Community Superintendents \n\n\r\n\t\t\t\t\t     \t\t\tHigh School Superintendents \n\n\r\n \t\t\t\t\t     \t\t\tBorough/Citywide Office Teams \n\n\r\n \t\t\t\t\t     \t\t\tSchool Principals \n\n \n\n\n\n\n\n\n\nFROM:    \n\n\n\n\nLindsey Oates, Chief Financial Officer\n\n\n\n\n\n\n\nSUBJECT:    \n\n\n\n\nContracts for Excellence (C4E) Discretionary Allocations to Schools\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nThis SAM distributes funding for the Contracts for Excellence (C4E) program in\r\n accordance with need weights issued by NYSED. \n\n \n\n\n\n\nNeed weights based on student attributes are updated annually by the New York State Education Department (NYSED), \r\nand may result in fluctuating school allocations from year to year.  .  As student needs change, schools may or may \r\nnot receive this allocation from year to year.\n\n\n\n\nThe Department of Education receives a portion of its overall budget in the form of Foundation Aid from New York State.\r\n This portion of Foundation Aid is subject to the provisions of C4E, which mandates that 75% of the city\'s total C4E funding\r\n go to the top 50% of needy schools, as identified through the State\'s need weight ranking system. Schools first implemented \r\nC4E in school year 2007-2008. C4E has been reauthorized for the 2021-2022 school year in the State\'s FY 2021-2022 Enacted Budget. \r\n\n\n The requirements under this School Allocation Memorandum (SAM) are subject to change pending NYSED\'s issuance of FY2021-2022 guidance.\n\n \n\n\n\n\n\n\n\nNon-discretionary C4E funds also support integrated co-teaching \r\n\n\n\n\n\n(\n\nSAM \r\nNo. 01\n\n)\n\n, autism spectrum disorder \r\n\n\n\n\n\n(\n\nSAM \r\nNo. 20\n\n)\n\n, and full day Pre-Kindergarten classrooms \r\n\n\n\n\n\n(\n\nSAM \r\nNo. 26\n\n)\n\n.\n\n\n\n\n\n\n\nHow Funds Should Be Spent\n\n\n\n\nSchools with existing C4E-funded programs first utilize these funds to continue or expand existing program efforts. \n\n\n\n\n All programs funded with C4E - whether maintenance of effort or new/expanded programs - must adhere to the following provisions \r\nand are subject to NYSED monitoring to ensure compliance:\n\n\n\n\n\n\n\n\n\n\n\n\n\nProgram Area Requirements\n\n:  C4E dollars must be spent to support programs \r\nand activities in the following six program areas:\r\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nClass Size Reduction\r\n\n\n\n\n\n\n\n\n\n\n\nStudent Time on Task\r\n\n\n\n\n\n\n\n\n\n\n\nTeacher and Principal Quality Initiatives\r\n\n\n\n\n\n\n\n\n\n\n\nMiddle School and High School Restructuring\r\n\n\n\n\n\n\n\n\n\n\n\nFull-Day Pre-Kindergarten; and\r\n\n\n\n\n\n\n\n\n\n\n\nModel Programs for Multilingual Language Learners\r\n\r\n\n\n\n\n\n\n\n\n\n\n\nFor more information on eligible program options within these six program areas, please see Appendix A of this SAM.\r\n\n\n\n\n\n\xa0\n\n\n\n\n\n\n\n\n\n\nStudents with the Greatest Educational Need\n\n:  C4E funds must be used to predominantly serve students with the greatest educational need, including:\r\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nMultilingual Language Learners (MLLs) and students with limited English proficiency;\r\n\n\n\n\n\n\n\n\n\n\n\nStudents with disabilities;\r\n\n\n\n\n\n\n\n\n\n\n\nStudents in poverty; and\r\n\n\n\n\n\n\n\n\n\n\n\nStudents with low academic achievement.\r\n\r\n\n\n\n\n\n\n\n\n\xa0\n\n\n\n\n\n\n\n\n\n\n\n\n\nSupplement not Supplant:\n\n  C4E programs must supplement programs funded by tax levy dollars,\r\n and funds distributed pursuant to this SAM may not be used to cover the costs of programs and personnel previously funded with tax levy dollar ...
#  {'Category': 'Collective Bargaining for School Based Staff',
#   'Galaxy Titles': ['TL CB School Staff',
#    'TL CB School Staff CW',
#    'TL CB School Staff D79'],
#   'Body': '\n\n\n\n\n\n\n\n\n\n\n\n\n\nNYCDOE Division of Finance Website Navigation\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSCHOOL ALLOCATION MEMORANDUM NO. 06, FY 2022\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nDATE:  \n\n\n\n\nJune 18, 2021\n\n\n\n\n\n\n\nTO:\n\n\n\n\nExecutive Superintendents \n\n\r\n\t\t\t\t\t    \t\t        Community Superintendents \n\n\r\n\t\t\t\t\t     \t\t\tHigh School Superintendents \n\n\r\n \t\t\t\t\t     \t\t\tBorough/Citywide Office Teams \n\n\r\n \t\t\t\t\t     \t\t\tSchool Principals \n\n \n\n\n\n\n\n\n\nFROM:    \n\n\n\n\nLindsey Oates, Chief Financial Officer\n\n\n\n\n\n\n\nSUBJECT:    \n\n\n\n\nCollective Bargaining for School Based Staff\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nThis memorandum allocates resources to schools to account for salary increases and other changes resulting from agreements with the Council of School Supervisors & Administrators (CSA)\r\n, the United Federation of Teachers (UFT), District Council 37 (DC 37), Communication Workers of America (CWA), and the agreement covering Managerial and Original Jurisdiction titles. \r\nFunding is provided for the annualized cost of increases implemented in FY 2021, as well as increases that will be implemented in FY 2022.  \r\n\n\n\n\n\nExternal funders, such as the federal government and the state, did not provide additional resources to help offset costs for collective bargaining.  \r\nAll collective bargaining was funded by the city.  This memorandum allocates supplemental tax levy funds to support increases incurred in major reimbursable funding streams.\r\n\n\n\n\n\nWhere possible, allocation adjustments for collective bargaining have been folded into existing tax levy allocation categories.  Where allocations are split-funded between tax levy and reimbursable sources,\r\nfunding was added to the tax levy allocation category to cover the cost of collective bargaining across the entire program.  By using this strategy, schools will only have to manage discrete collective \r\nbargaining allocations in minimal instances.  Where collective bargaining is included in program allocations, details are provided in the program allocation memorandum.\r\n\n\n\n\n\nSome programs will have to bear the cost of salary increases, e.g. private, foundation, City Council, intra-city, and self-sustaining grants.  \r\nFunding for collective bargaining increases for services in competitive grants must be self-funded within the grant award amount.  \r\nTherefore, all grant proposals and applications must account for collective bargaining increases in future fiscal years as per current labor agreements.\r\n\n\n\n\n\nPer Session, Per Diem, Prep Coverage, and F Status Rates\n\n\n\n\nAverage teacher salaries, city-wide average salaries for mandated services, such as speech and counseling, and forecast actual salaries of staff have \r\nbeen updated in Galaxy for all known collective bargaining payroll events.\r\n\n\n\n\n\nGalaxy Updated for New Rates for FY 2022\n\n\n\n\nWhere selected titles will receive collective bargaining increases at various dates throughout FY 2022, multiple rates of pay will be in effect over the course of the year.  \r\nIn order to normalize these varying rates and effective dates for annual budgeting purposes, the rates in Galaxy for scheduling selected bulk job titles are based on the "cash value" for each title.  \r\nThe cash value is the net amount of the increase paid over the course of the entire fiscal year for all payroll dates, based on the percentage increase and effective date.  \r\nThe "cash value" rate will be used for scheduling budget items for titles in unions with increases occurring in the latter part of the year.  \r\nFor unions with collective bargaining increases that take place earlier in the year, the rate will reflect the collective bargaining increase for the entire year.  \r\nFor other titles cumulative increases through the end of FY 20 ...
#  {'Category': 'Summer Rising',
#   'Galaxy Titles': ['ARPA, Title III, and Title IV',
#    'ARPA Academic Recovery Remote Summer Rising',
#    'ARPA Academic Recovery CBO Summer Rising',
#    'TL Summer Rising Shared',
#    'ARPA Academic Recovery Summer Rising',
#    'ARPA Academic Recovery Summer Rising',
#    'ARPA Academic Recovery Summer Rising',
#    'TL Summer Rising Shared',
#    'ARPA Academic Recovery Summer Rising',
#    'TL Summer Rising Shared',
#    'ARPA Academic Recovery AP Summer Rising',
#    'Title IV Safe Healthy Counseling Summer Rising',
#    'ARPA Academic Recovery Para Summer Rising ',
#    'TL Summer Rising Shared ',
#    'ARPA Academic Recovery Summer Rising ',
#    'Title III Summer Rising ML Support.',
#    'ARPA Academic Recovery SE Support Summer Rising',
#    'ESY Summer Rising Services RS',
#    'TL RS ESY Summer Rising Services',
#    'TL Summer Rising ASD',
#    'ARPA Academic Recovery Summer Rising ASD',
#    'ARPA',
#    'TL Summer Rising Pre-K SE',
#    'TL Summer Rising Discovery Program',
#    'ARPA Academic Recovery CTE Summer Rising',
#    'ARPA Academic Recovery Arts Summer Rising',
#    'ARPA Academic Recovery WBL Summer Rising',
#    'TL Summer Rising Support Shared'],
#   'Body': '\n\n\n\n\n\n\n\n\n\n\n\n\n\nNYCDOE Division of Finance Website Navigation\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSCHOOL ALLOCATION MEMORANDUM NO. 07, FY 2022\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nRevised January 14, 2022 \n\n\n\n\n\n\n\nDATE:  \n\n\n\n\nMay 17, 2021\n\n\n\n\n\n\n\nTO:\n\n\n\n\nExecutive Superintendents \n\n\r\n\t\t\t\t\t    \t\t        Community Superintendents \n\n\r\n\t\t\t\t\t     \t\t\tHigh School Superintendents \n\n\r\n \t\t\t\t\t     \t\t\tBorough/Citywide Office Teams \n\n\r\n \t\t\t\t\t     \t\t\tSchool Principals \n\n \n\n\n\n\n\n\n\nFROM:    \n\n\n\n\nLindsey Oates, Chief Financial Officer\n\n\n\n\n\n\n\nSUBJECT:    \n\n\n\n\nSummer Rising\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\r\nThis memorandum is being issued for planning purposes in advance of the funding being allocated to schools in Galaxy.  Funding will be entered in Galaxy on May 24, 2021 as per the tables linked below.\r\n\n\n\n\n\n\r\nThis memorandum funds the Summer Rising program, a bold vision for summer learning that is student-centered, experiential and academically rigorous. \r\nSummer Rising provides summer instructional opportunities for all students while continuing to serve mandated students in grades 3-8, and high school students in need of credits towards graduation.  \r\nThe Summer Rising programs is a continuation of our work to deliver equity and excellence to all students and a response to the current needs of our students. Two days of professional development will be provided for teachers, and one day of professional development\r\nwill be provided for education paraprofessionals.  Funds for professional development will be allocated directly to schools. \r\n\n\n\n\n\nAmerican Rescue Plan Act (ARPA) Overview\n\n\n\n\n\r\nOn March 11, 2021, the President signed into law the American Rescue Plan Act of 2021 (ARPA).  Funds must be used to help meet a wide range of needs arising from the coronavirus pandemic, \r\nincluding activities and interventions that respond to students\' academic, social and emotional needs and address the disproportionate impact of COVID-19 on underrepresented student subgroups.  \r\nARPA funds are temporary and supplemental.\r\n\n\n\n\n\nARPA for Academic Recovery\n\n\n\n\nIn accordance with the state and federal ARPA guidance, school districts must use a portion of funds to support academic recovery activities or what the United States Department of Education (USDOE) refers to as the "learning loss".\r\n\n\n\n\n\n\r\nAcademic recovery activities offered in the Summer Rising program will be funded by ARPA. As these are federal stimulus funds, they cannot be transferred from school-to-school, and must be maintained and scheduled in the allocated school location.  \r\n\n\n\n\n\nSummer Rising Budget Modification Due Date and FS10s\n\n\n\n\nAll streams of Summer Rising funding should be fully scheduled by schools and approved by BCOs by \n\n4:00 pm on July 16, 2021.\n\n  As many program components are funded using \n\nARPA, Title III, and Title IV\n\n, \r\nall programs must be fully scheduled by schools and approved by BCOs for the FS10 snapshot to be taken. Approved funds will appear on the city\'s FS10 financial document and will be submitted along with \r\nbudget narratives for review and approval by NYSED.  All ESSA funds should be scheduled in support of the school CEP.\r\n\n\n\n\n\nSummer Rising programs offered this year include:\r\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSummer Rising Academic Support\n\n\n\n\nNew Supports for Summer Rising Programs\n\n\n\n\nSummer Rising Support for Multilingual Learners\n\n\n\n\nSummer Rising Support for Students with Disabilities\n\n\n\n\nExtended School Year Summer Rising (ESY)\n\n\n\n\nASD/Nest/Horizon Summer Rising Programs\n\n\n\n\nSummer Rising Pre-K Class ESY Program\n\n\n\n\nSummer Rising Discovery Program\n\n\n\n\nCTE Summer Enrichment\n\n\n\n\nArtist Murals and Pop Up Performance Grants ...
#  {'Category': 'FY 2021 Deficit Rollover Relief',
#   'Galaxy Titles': ['TL CRRSA FSF Deficit Relief',
#    'TL CRRSA FSF Deficit Relief HS'],
#   'Body': '\n\n\n\n\n\n\n\n\n\n\n\n\n\nNYCDOE Division of Finance Website Navigation\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSCHOOL ALLOCATION MEMORANDUM NO. 08, FY 2022\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nRevised April 12, 2022 \n\n\n\n\n\n\n\nDATE:  \n\n\n\n\nJune 18, 2021\n\n\n\n\n\n\n\nTO:\n\n\n\n\nExecutive Superintendents \n\n\r\n\t\t\t\t\t    \t\t        Community Superintendents \n\n\r\n\t\t\t\t\t     \t\t\tHigh School Superintendents \n\n\r\n \t\t\t\t\t     \t\t\tBorough/Citywide Office Teams \n\n\r\n \t\t\t\t\t     \t\t\tSchool Principals \n\n \n\n\n\n\n\n\n\nFROM:    \n\n\n\n\nLindsey Oates, Chief Financial Officer\n\n\n\n\n\n\n\nSUBJECT:    \n\n\n\n\nFY 2021 Deficit Rollover Relief\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nEach year, schools are responsible for rollover deficits where they did not pay back funds owed for register loss in the prior fiscal year.  However, as school year 2020-21 \r\nenrollment projections were developed prior to the pandemic, they did not account for the greater than normal enrollment fluctuations most schools experienced. For FY 2021 \r\nonly, in recognition of the pandemic-driven enrollment declines, restoration allocations were provided to fully offset funds schools owed for mid-year register adjustments \r\nfor larger than projected register loss.  These funds were allocated in FY 2021 \r\n\n\nSAM 79 School COVID-19 Register Loss Mid-Year Adjustment Restoration\n\n.\r\n\n\n\n\n\nIn addition, all rollover deficits for years prior to FY 2021, unpaid school-funded copier costs, and "O to Q" teacher grievances have been forgiven.  No deficits will be \r\nrolled into FY 2022. Federal stimulus funding will support deficit rollover relief for FY 2022, and schools are expected to use deficit relief funding for eligible purposes \r\nas per school CEPs.\n\n\n\n\nAccountability\n\n\n\n\nPrincipals are responsible for ensuring that they do not over-expend their school allocations.  Principals must work closely with Borough/Citywide Office (BCO) budget staff \r\nto ensure service levels and budget schedules are aligned with pupil need. Principals and their designees should work closely with their BCO budget director to understand the \r\nimplications of changing registers and student attendance on an on-going basis from now until registers are stabilized in the fall.\n\n\n\n\nReserve for Register Loss/Gain and Register Monitoring\n\n\n\n\nIn order to assist schools in planning for potential register loss, "Register Loss and/or Reserve Gain Set Aside" has been automatically scheduled on their Galaxy TO. Refer \r\nto \n\nSAM 01 Fair Student Funding\n\n \r\nfor details on how reserves are developed, and for the updated policy for FY 2022.\n\n\n\n\nSchools should work with their BCO budget director to release reserved funds only when actual registers are stable, and principals are confident in their school\'s student \r\ndata and can provide documentation that registers have attained allocated levels.\n\n\n\n\nSchools can consider excessing staff as needed to downsize to meet their set aside target. Schools taking such action should notify staff being excessed before school closes.  \r\nAll excess actions are subject to financial review and approval by the BCO.\n\n\n\n\nOther School Financial Responsibilities\n\n\n\n\nSchools are responsible for school-funded copier costs and "O to Q" teacher grievances. In order to avoid future rollover deficits, schools should ensure proper action is \r\ntaken to schedule funds to pay for copiers, and avoid hiring practices that may result in future "O to Q" teacher grievances.\n\n\n\n\nCoronavirus Response and Relief Supplemental Appropriations Act (CRRSA) Overview\n\n\n\n\nOn December 27, 2020, the President signed into law the Coronavirus Response and Relief Supplemental Appropriations Act of 2021 (CRRSA). Funds must be used to help meet a wide range of \r\nneeds arising from the coronavirus pandemic, ...
#  {'Category': 'School Budget Surplus Rollover',
#   'Galaxy Titles': ['TL CRRSA Surplus Rollover (HS)(CW) ',
#    'TL CRRSA Surplus Rollover, TL CRRSA Surplus Rollover HS, TL CRRSA Surplus Rollover CW'],
#   'Body': '\n\n\n\n\n\n\n\n\n\n\n\n\n\nNYCDOE Division of Finance Website Navigation\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSCHOOL ALLOCATION MEMORANDUM NO. 09, FY 2022\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nRevised January 14, 2022\n\n\n\n\n\n\n\nDATE:  \n\n\n\n\nJune 18, 2021\n\n\n\n\n\n\n\nTO:\n\n\n\n\nExecutive Superintendents \n\n\r\n\t\t\t\t\t    \t\t        Community Superintendents \n\n\r\n\t\t\t\t\t     \t\t\tHigh School Superintendents \n\n\r\n \t\t\t\t\t     \t\t\tBorough/Citywide Office Teams \n\n\r\n \t\t\t\t\t     \t\t\tSchool Principals \n\n \n\n\n\n\n\n\n\nFROM:    \n\n\n\n\nLindsey Oates, Chief Financial Officer\n\n\n\n\n\n\n\nSUBJECT:    \n\n\n\n\nSchool Budget Surplus Rollover\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nThe School Budgets Surplus Rollover (SBSR) was offered in FY 2021. The program is able to be offered this year only due to federal stimulus and is not a restart of the \r\nannual program offered in recent years. The SBSR allows schools that generated accruals in select allocation categories to transfer those accruals into the school\'s FY 2022 budget. \r\nAll schools in Community School Districts 1-32, Citywide Special Education District 75/97, and Alternative Programs District 79, which meet the eligibility requirements were allowed \r\nto participate in the program.  \r\n\n\n\n\n\nIn prior rollover programs, only schools in good fiscal and academic standing that have accruals to transfer funds into next year\'s budgets were able to participate. \r\nDue to the COVID-19 pandemic and the resulting cancellations of state testing in the 2019-2020 school year, as well as the opportunity for waivers for the NYSITELL tests for \r\nEnglish language learners in 2020-2021 certain eligibility criteria were not included. Therefore, academic criteria and ELL compliance rates were not included in the eligibility criteria. \r\nSchools only rolled over funding after all student needs in FY 2021 were met.\r\n\n\n\n\n\nCoronavirus Response and Relief Supplemental Appropriations Act (CRRSA) Overview\n\n\n\n\nOn December 27, 2020, the President signed into law the Coronavirus Response and Relief Supplemental Appropriations Act of 2021 (CRRSA). Funds must be used to help meet a \r\nwide range of needs arising from the coronavirus pandemic, including activities and interventions that respond to students\' academic, social and emotional needs and \r\naddress needs essential to keeping schools open. CRRSA funds are temporary and funds allocated for the rollover deficit relief/surplus rollover can be used similarly \r\nto tax levy FSF allocations in FY 2022.\r\n\n\n\n\n\nAllocations funded with these stimulus dollars will have "CRRSA" be noted in the allocation category (AC). Cost factors in Galaxy associated with these ACs may be limited. \r\nSchools are responsible for reviewing SAM documentation and guidance to ensure that funding is used for eligible purposes only as outlined in this SAM.\r\n\n\n\n\n\nCRRSA funding allocated for deficit relief/surplus rollover is available for expenses incurred July 1, 2021 through June 30, 2022. Schools are encouraged to schedule \r\nfunds and implement eligible programming as soon as possible. CRRSA stimulus funding is temporary, and should not be expected in subsequent school years. \r\nAdditionally, schools should be mindful of long-term budget sustainability of any new programming supported with stimulus funding. As with all federal funding, \r\nthese funds are subject to monitoring and audit. All purchasing and payroll documentation, including timesheets, must be retained on site at the school to support \r\nexpenditures, and must be available to present upon request.\r\n\n\n\n\n\nAllocation Procedure for FY 2021 Funds Rolled to FY 2022\n\n\n\n\nSchools were able to rollover funds based on their audited November 13, 2020 registers up to a per capita rate of $72 per student.\r\n\n\n\n\n\nOf the amount carried into FY 20 ...
#  {'Category': 'New York State Textbook Law (NYSTL), Library, Software and Hardware Allocation',
#   'Galaxy Titles': ['TL NYSTL Hardware',
#    'TL NYSTL Hardware HS',
#    'TL NYSTL Hardware CW',
#    'TL NYSTL Library',
#    'TL NYSTL Library HS',
#    'TL NYSTL Library CW',
#    'TL NYSTL Software',
#    'TL NYSTL Software HS',
#    'TL NYSTL Software CW',
#    'TL NYSTL Textbooks',
#    'TL NYSTL Textbooks HS',
#    'TL NYSTL Textbooks CW'],
#   'Body': '\n\n\n\n\n\n\n\n\n\n\n\n\n\nNYCDOE Division of Finance Website Navigation\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSCHOOL ALLOCATION MEMORANDUM NO. 10, FY 2022\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nDATE:  \n\n\n\n\nMay 17, 2021\n\n\n\n\n\n\n\nTO:\n\n\n\n\nExecutive Superintendents \n\n\r\n\t\t\t\t\t    \t\t        Community Superintendents \n\n\r\n\t\t\t\t\t     \t\t\tHigh School Superintendents \n\n\r\n \t\t\t\t\t     \t\t\tBorough/Citywide Office Teams \n\n\r\n \t\t\t\t\t     \t\t\tSchool Principals \n\n \n\n\n\n\n\n\n\nFROM:    \n\n\n\n\nLindsey Oates, Chief Financial Officer\n\n\n\n\n\n\n\nSUBJECT:    \n\n\n\n\nNew York State Textbook Law (NYSTL), Library, Hardware and Computer \r\n\tSoftware (NYSSL) Funds\r\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\r\nThis memorandum is being issued for planning purposes in advance of the funding being allocated to schools in Galaxy.  Funding will be entered in Galaxy on May 24, 2021 as per the tables linked below.\r\n\n\n\n\n\nState Aid provides funds for Textbooks, Library Books, Computer Software and Hardware for students in grades K-12 to help improve technology and instruction in schools.  \r\nEach funding stream has a specific purpose as detailed below.  This memorandum allocates these resources to schools as per the attached table.  \r\nAllocations are final, and will not be adjusted later in the year based on register changes.\r\n\n\n\n\n\nPurchases must be approved NYSTL-eligible items, as indicated in the ShopDOE catalogue.  \r\nCertain Microsoft and anti-virus software programs will be purchased centrally and be available to all schools, at no cost.  \r\nState Software revenue will be set aside to cover the cost of the related contracts.\r\n\n\n\n\n\nUnder the New York State Textbook Law (NYSTL) and New York State Software Law (NYSSL), the State provides aid at the lesser of:\n\n\n\n\n\n\n\nA per capita amount based on the prior year\'s enrollment multiplied by the State\'s per pupil rate, or\n\n\n\n\nThe prior year\'s expenditure. (We expect to maximize expenditures in order to maintain this allocation for future years.)\n\n\n\n\n\n\n\nAllocations to schools are based on a per capita rate as follows:\n\n\n\n\n\n\n\n\n\n\n\n\n\nAllocation\n\n\n\n\nPer Capita\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nNYS Software\n\n\n\n\n$ 9.84\n\n\n\n\n\n\n\n\n\n\nNYS Hardware\n\n\n\n\n$ 10.70\n\n\n\n\n\n\n\n\n\n\nNYS Library\n\n\n\n\n$ 6.26\n\n\n\n\n\n\n\n\n\n\nNYS Textbooks\n\n\n\n\n$ 58.05\n\n\n\n\n\n\n\n\n\n\n\n\n\nSchool Register Data\n\n\n\n\nThe allocations are based on the November 13, 2020 audited registers for grades K-12, with adjustments for registers of approved restructurings for additional grades.\r\nWhere school are approved to merge in FY 2022, audited registers of the dissolving schools have been combined with the audited registers of the prevailing schools.  \r\nNew school allocations are based on their projected registers for FY 2022.\r\n\n\n\n\n\nFlexible & Fixed Funding\n\n\n\n\nNYSTL Textbook, Hardware and Software funds can be used interchangeably.  Although the distinct allocation categories are being maintained in Galaxy in the initial \r\nallocation, schools can modify the auto-scheduled items in these allocation categories into any of the other NYSTL titles. NYSTL Library funds must be maintained as auto-scheduled\r\nin Galaxy in the title "Library Books" and cannot be modified.  However, NYSTL Hardware, Software and Textbook can be utilized to purchase library books.  \r\nThe title "Library Books" is included in the cost factors for these allocation categories in Galaxy.\r\n\n\n\n\n\nCore Curriculum\n\n\n\n\nNYSTL aid (Textbook, Hardware & Software) will be used to offset Core Curriculum costs for participating schools.\n\n\n\n\nWhile NYSTL allocations cover the costs for the majority of schools maintaining existing Core Curriculum programs, some school orders may exceed their allocations.  \r ...
#  {'Category': 'Title I School Allocations',
#   'Galaxy Titles': ['Title I CSI Participatory Budget',
#    'Title I SWP',
#    'Title I Targeted Assistance',
#    'Title I SWP STH',
#    'Title I TA STH',
#    'Title I STH for Non Title I Schools',
#    'High Need Support for Title I',
#    'High Need Support for Title I STH',
#    'Title I SWP Parent and Family Engagement',
#    'Title I TA Parent and Family Engagement',
#    'Title I SWP Carry Over',
#    'Title I TA Carry Over',
#    'Title I SWP Carry Over Parent and Family Engage',
#    'Title I TA Carry Over Parent and Family Engage',
#    'Title I 1003a TSI/CSI PS',
#    'Title I 1003a TSI/CSI OTPS'],
#   'Body': '\n\n\n\n\n\n\n\n\n\n\n\n\n\nNYCDOE Division of Finance Website Navigation\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSCHOOL ALLOCATION MEMORANDUM NO. 11, FY 2022\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nDATE:  \n\n\n\n\nJune 18, 2021\n\n\n\n\n\n\n\nTO:\n\n\n\n\nExecutive Superintendents \n\n\r\n\t\t\t\t\t    \t\t        Community Superintendents \n\n\r\n\t\t\t\t\t     \t\t\tHigh School Superintendents \n\n\r\n \t\t\t\t\t     \t\t\tBorough/Citywide Office Teams \n\n\r\n \t\t\t\t\t     \t\t\tSchool Principals \n\n \n\n\n\n\n\n\n\nFROM:    \n\n\n\n\nLindsey Oates, Chief Financial Officer\n\n\n\n\n\n\n\nSUBJECT:    \n\n\n\n\nTitle I School Allocations\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\r\nThis memorandum allocates Title I funding to schools to support the following programs:\r\n\n\n\n\n\n\n\n\nTitle I Allocation per capita\n\n\n\n\nTitle I 1003(a) Basic School Improvement Grant\n\n\n\n\nTitle I 1003(a) for Participatory Budgeting\n\n\n\n\n\n\n\nTitle I Overview\n\n\n\n\n\r\nTitle I funds must be used to provide all children significant opportunities to receive a fair, equitable and high-quality education and to close educational achievement gaps.  While the US Department of Education (USDE) provides funding based on the number of low-income students between the ages of 5 and 17 according to the census, resources are primarily for supplemental educational services targeted at academically at-risk students.\r\n\n\n\n\n\n\r\nDue to the coronavirus pandemic, the closing of schools, and remote learning, the department is expecting a decrease in expenditures originally reserved for supplemental activities and professional development. As a result, Title I public schools will have a one-time only allocation of carry over funds in addition to the FY 2022 base allocation.  This one-time allocation is to be used in support of the school\'s comprehensive education plan, is subject to all Title I spending requirements, as well as applicable DOE hiring restrictions, and will not be available in FY 2023. \r\n\n\n\n\n\nEvery Student Succeed Act (ESSA)\n\n\n\n\n\r\nThe Every Student Succeeds Act (ESSA) reauthorizes the Elementary and Secondary Education Act (ESEA) of 1965, effective school year 2017-2018.  Allocations of federal dollars must utilize funding methodologies mandated by the reauthorization, which modifies the distribution of Title I funds to public and non-public schools based on eligible low-income students attending Title I attendance zone schools. \r\n\n\n\n\n\n\r\nPlease note that all federal funding issued in FY 2022 is preliminary and subject to final allocation by the New York State Education Department (NYSED).\r\n\n\n\n\n\nPublic School Allocations\n\n\n\n\n\r\nTitle I funds are proportionally distributed to public and non-public schools. For public schools, required set-asides include funding for parent and family engagement, students in temporary housing, and neglected students, which are allocated separately to schools. Title I funding, net of these adjustments, is allocated to elementary, middle, and high schools on a per capita basis using the number of eligible children in each borough attending Title I designated schools. Special education classes, provided in compliance with students\' Individual Education Program (IEP), reduces the need for supplemental Title I services.  As a result, Citywide Special Education Title I resources will be used to enhance supplementary Title I programs in elementary, middle, and high schools in all schools.  This policy has been in effect since FY 1994. District 75 schools, however, will receive a Title I allocation for students in temporary housing. \r\n\n\n\n\n\n\r\nThe preliminary public school Title I county per capitas are:\r\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nCity-Wide\n\n\n\n\nManhattan\n\n\n\n\nBronx\n\n\n\n\nBrooklyn\n\n\n\n\nQueens\n\n\n\n\nStaten Island\n\n\n\n\n\n\n\n\n\n\nPublic School Alloca ...
#  {'Category': 'Title IIA Supplement',
#   'Galaxy Titles': [],
#   'Body': "\n\n\n\n\n\n\n\n\n\n\n\n\n\nNYCDOE Division of Finance Website Navigation\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSCHOOL ALLOCATION MEMORANDUM NO. 12, FY 2022\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nDATE:  \n\n\n\n\nJune 18, 2021\n\n\n\n\n\n\n\nTO:\n\n\n\n\nExecutive Superintendents \n\n\r\n\t\t\t\t\t    \t\t        Community Superintendents \n\n\r\n\t\t\t\t\t     \t\t\tHigh School Superintendents \n\n\r\n \t\t\t\t\t     \t\t\tBorough/Citywide Office Teams \n\n\r\n \t\t\t\t\t     \t\t\tSchool Principals \n\n \n\n\n\n\n\n\n\nFROM:    \n\n\n\n\nLindsey Oates, Chief Financial Officer\n\n\n\n\n\n\n\nSUBJECT:    \n\n\n\n\nTitle IIA Supplement\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\r\nThis memorandum allocates federal funds under Title IIA to reduce class size across the system. \r\n\n\n\n\n\nEvery Student Succeed Act (ESSA) \n\n\n\n\n\r\nTitle IIA Supplement funding is authorized under the Every Student Succeed Act (ESSA).  Funding has been gradually reduced for the past few years, and reductions will likely continue in future years.  Title IIA funding is based on a weighted proportion of the LEA students, where the number of low-income students from the ages of 5 to 17 make up 80% of the formula, and the student population from the ages of 5 to 17 make up 20% of the formula.  Funds are also proportionally distributed to public and non-public schools.\r\n\n\n\n\n\n\r\nFor FY 2022, the department has received a significant reduction in Title IIA funds.  This reduction is primarily due to the state's completion of its Title IIA Corrective Action Plan. As a result, the annual reduction in funding will not be offset by funds allocated from the corrective action plan. Allocations contained in this memorandum are preliminary and subject to change during the year.  Final allocations will be subject to final NYSED allocations to LEAs and congressional authorization.  \r\n\n\n\n\n\n\r\nThe Title IIA Supplemental allocation gives priority to schools where classes are in excess of 20 pupils and academic performance is poor.  The first priority is to use funds to reduce class size in a grade.  If space is not available to form additional classes, funds may support push-in teachers to supplement the instructional program.  Priority must be given to reducing class size in general education settings and must demonstrate the following: \r\n\n\n\n\n\n\n\n\nReduction of class sizes to 15-18 students or fewer (including the use of co-teaching and floating teachers that bring the student to teacher ratio to one teacher per 15-18 students);\n\n\n\n\nA rigorous curriculum, effective teachers, and a sustained, job-embedded professional development plan.\n\n\n\n\n\n\n\n\r\nPlease note that all teachers funded by this allocation must have state certification and licensure standards as per ESSA.  Principals have received reports from the Division of Human Capital detailing the status of their current staff.  Schools will budget all teacher positions at their average salary.\r\n\n\n\n\n\nGuidelines for Calculating Class Size Reduction\n\n\n\n\n\r\nClasses created through the Federal Title IIA Supplemental program may not include classes that would have been organized absent the program.  The overall total of teachers must be greater than the number of teachers required by the contract.  For example, a school with a grade 1 enrollment of 60 students, under the UFT Collective Bargaining Agreement, would be required to organize two classes.  If the school funds only two grade 1 teachers, no Title IIA Supplemental funds may be used.  The school could fund a third classroom or fund a push-in teacher for the two contractually required classes.  Note that contractual class sizes limits are 25 for kindergarten and 32 for grades 1 through 3.\r\n\n\n\n\n\n\r\nThere are many situations that could result in different class formations, such as organizing bilingual classes or inclusion class ...
#  {'Category': 'School Support Supplement',
#   'Galaxy Titles': [' School Support Supplement '],
# ...
#  {'Category': ' Community Schools Expansion Planning ',
#   'Galaxy Titles': ['ARPA Academic Recovery Community Schools Expansion.'],
#   'Body': "\n\n\n\n\n\n\n\n\n\n\n\n\n\nNYCDOE Division of Finance Website Navigation\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSCHOOL ALLOCATION MEMORANDUM NO. 98, FY 2022\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nDATE:  \n\n\n\n\nApril 1, 2022\n\n\n\n\n\n\n\nTO:\n\n\n\n\nExecutive Superintendents \n\n\r\n\t\t\t\t\t\t\t\tCommunity Superintendents \n\n\r\n\t\t\t\t\t     \t\t\tHigh School Superintendents \n\n\r\n \t\t\t\t\t     \t\t\tBorough/Citywide Office Teams \n\n\r\n \t\t\t\t\t     \t\t\tSchool Principals \n\n \n\n\n\n\n\n\n\nFROM:    \n\n\n\n\nLindsey Oates, Chief Financial Officer\n\n\n\n\n\n\n\nSUBJECT:    \n\n\n\n\nCommunity Schools Expansion Planning\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nThis allocation funds selected Community Schools that have been identified by the Office of Community Schools (OCS) as requiring planning services support.\r\n\n\n\n\n\nAmerican Rescue Plan Act (ARPA)\n\n\n\n\nOn March 11, 2021, the President signed into law the American Rescue Plan Act of 2021 (ARPA). Funds provided through ARPA must be used to help meet a wide range of needs \r\narising from the coronavirus pandemic, including activities and interventions that respond to students' academic, social and emotional needs and address the disproportionate \r\nimpact of COVID-19 on underrepresented student subgroups. ARPA funds are temporary and supplemental.\r\n\n\n\n\n\nIn accordance with the state and federal ARPA guidance, school districts must use a portion of funds to support academic recovery activities or what the United States Department \r\nof Education (USDE) refers to as academic impact of lost instructional time.  The activities designated in this SAM are intended to meet this requirement, and these funds must be \r\nspent in accordance with the parameters outlined below.  As with all federal funding, these funds are subject to monitoring and audit. All purchasing and payroll documentation, \r\nincluding timesheets, must be retained on site at the school to support expenditures, and must be available to present upon request.\r\n\n\n\n\n\nProgram Details\n\n\n\n\nThe NYCDOE's community school approach is based on a growing body of evidence showing that an integrated focus on academics, health and mental health services, youth development, \r\nexpanded learning opportunities, and family and community support are critical to improving student success. Each school will work with their designated Borough Citywide Office (BCO) \r\nBudget Director and with support from an OCS Director of School Support to plan for how to utilize the funds accordingly. All funds must be pre-encumbered and liquidated, as appropriate,\r\n to support Community School programs and services, and funds may only be used for these purposes. Schools will be required to complete a work plan to be submitted to and approved by \r\nOCS. This funding must also be spent in alignment with the Community Schools Fiscal and Operations Manual. The allocation per school or campus will be used for implementing the Assets \r\nand Needs Assessment and for initial programs and services aligned to the core features of a Community School, per below. \r\n\n\n\n\n\nFor the 2021-2022 school year, the allocation will cover planning supports as follows: \r\n\n\n\n\n\n\n\n\nCommunity Schools will receive support from OCS, including a Director of School Support to allocate funding and complete a work plan. \r\n\t\tSchools will have the option to contract with DOE-approved vendors. Schools should work with their BCO Budget Director and/or procurement \r\n\t\tspecialist to ensure Standard Operating Procedures are followed for all SAM procurements and vendor engagements.\n\n\n\n\nThese funds can be used to provide per session activities. Schools are encouraged to identify a program lead to support with coordination.\n\n\n\n\nBudget codes requested are for per session, professional services and reimbursement for student and ...
#  {'Category': ' Implicit Bias Awareness Workshops ',
#   'Galaxy Titles': ['TL Implicit Bias Awareness',
#    'TL Implicit Bias Awareness CW',
#    'TL Implicit Bias PL',
#    'TL Implicit Bias PL CW'],
#   'Body': "\n\n\n\n\n\n\n\n\n\n\n\n\n\nNYCDOE Division of Finance Website Navigation\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSCHOOL ALLOCATION MEMORANDUM NO. 99, FY 2022\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nDATE:  \n\n\n\n\nApril 7, 2022\n\n\n\n\n\n\n\nTO:\n\n\n\n\nExecutive Superintendents \n\n\r\n\t\t\t\t\t    \t\t        Community Superintendents \n\n\r\n\t\t\t\t\t     \t\t\tHigh School Superintendents \n\n\r\n \t\t\t\t\t     \t\t\tBorough/Citywide Office Teams \n\n\r\n \t\t\t\t\t     \t\t\tSchool Principals \n\n \n\n\n\n\n\n\n\nFROM:    \n\n\n\n\nLindsey Oates, Chief Financial Officer\n\n\n\n\n\n\n\nSUBJECT:    \n\n\n\n\nImplicit Bias Awareness Workshops\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nThis memorandum provides supplemental funding to support increased awareness of implicit bias and culturally responsive education.\r\n\n\n\n\n\nThe current social, economic and political climate, both within New York City and across the country, suggests a need for implicit bias awareness\r\nand culturally responsive programs that build inclusive, nurturing, and collaborative communities. While implicit bias cannot be eliminated, its effects \r\ncan be reduced and mitigated. Educators and school leaders can use this awareness to craft and build new learning experiences, for all students and stakeholders, in a child's life.\r\n\n\n\n\n\nWithin the New York City Department of Education (NYCDOE), the importance of this implicit bias and culturally responsive work is heightened as district and school staff make decisions, \r\non behalf of children, or interact with students on a daily basis. NYCDOE will work to fulfill the goals of increasing awareness about implicit bias and of \r\nreducing these biases by providing the Implicit Bias Awareness (IBA) workshops and the Facing History and Ourselves professional learning series. Inherent in this training will be a \r\nfocus on developing stakeholders' critical consciousness to promote greater systemic equity. \r\n\n\n\n\n\nGoals of the Implicit Bias Awareness (IBA) Sessions:\n\n\n\n\nDuring the sessions participants will learn about:\n\n\n\n\n\n\n\nImplicit bias\n\n\n\n\nThe brain science behind implicit bias\n\n\n\n\nHow biases show up in society, the classroom and the school community\n\n\n\n\nStrategies to mitigate the effects of our biases\n\n\n\n\n\n\n\nParticipating schools agree to:\n\n\n\n\n\n\n\nIntentionally identify appropriate stakeholders to complete the online Implicit Bias Awareness Sessions. \r\n\t\t\tThere are three self-paced modules that participants must complete before participating in the live Module 4 session.\n\n\n\n\nIdentify a coordinator to liaise with the Office of Equity and Access IBA team to confirm stakeholder attendance and to process time sheets.\n\n\n\n\nFunds may only be used to support per session for participants in the Implicit Bias Awareness sessions. \r\n\t\t\tAll standard operating procedures and fiscal year deadlines for procurement with tax levy funds apply.\n\n\n\n\n\n\n\nImplicit Bias Awareness (IBA) Funds should be scheduled using the allocation category \n\nTL Implicit Bias Awareness\n\n or \n\nTL Implicit Bias Awareness CW\n\n.\n\n\n\n\nGoals of the Implicit Bias Professional Learning Series:\n\n\n\n\nDuring the sessions participants will learn about:\n\n\n\n\n\n\n\nCulturally responsive and sustaining practices\n\n\n\n\nEngaging in a deep analysis of history to challenge participants to stand up to bigotry and hate\n\n\n\n\nDeveloping understanding of equity research\n\n\n\n\n\n\n\nParticipating schools agree to:\n\n\n\n\n\n\n\nEnsure selected staff complete four 90-minute sessions\n\n\n\n\nIdentify a coordinator to liaise with the OEA team to confirm stakeholder attendance and to process time sheets on a monthly basis\n\n\n\n\n\n\n\nFunds may only be used to support per session for participants in the Implicit Bias Professional Learning series.\n\n\n\n\nFunds should be  ...
#  {'Category': ' Regents Distributed Scoring ',
#   'Galaxy Titles': ['TL Regents Distributed Scoring ', 'TL LOTE'],
#   'Body': '\n\n\n\n\n\n\n\n\n\n\n\n\n\nNYCDOE Division of Finance Website Navigation\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSCHOOL ALLOCATION MEMORANDUM NO. 100, FY 2022\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nDATE:  \n\n\n\n\nApril 8, 2022\n\n\n\n\n\n\n\nTO:\n\n\n\n\nExecutive Superintendents \n\n\r\n\t\t\t\t\t    \t\t        Community Superintendents \n\n\r\n\t\t\t\t\t     \t\t\tHigh School Superintendents \n\n\r\n \t\t\t\t\t     \t\t\tBorough/Citywide Office Teams \n\n\r\n \t\t\t\t\t     \t\t\tSchool Principals \n\n \n\n\n\n\n\n\n\nFROM:    \n\n\n\n\nLindsey Oates, Chief Financial Officer\n\n\n\n\n\n\n\nSUBJECT:    \n\n\n\n\nRegents Distributed Scoring\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nThis allocation funds scoring of Regents exams at citywide distributed scoring sites as well as funds for hub site testing for World Language (previously LOTE) Exams. \n\n\n\n\nJune 2022 Regents Scoring\n\n\n\n\nAccording to NYSED policy, NYCDOE will continue to utilize a distributed scoring program in which staff members cannot score \r\nRegents exams of students that attend their school. This applies to all schools that administer Regents exams.\n\n\n\n\nJune 2022 Regents scoring will take place from June 2 through June 7 and June 16 through June 28 and will be completed through a combination \r\nof scoring during the school day and scoring in the evenings and on the weekends (a.k.a. per session scoring).\n\n\n\n\nThis allocation is to support scoring of Regents exams at citywide distributed scoring sites. The allocations may be used as \r\ndetermined by the principals of the host Regents scoring sites:\n\n 1) to cover per session activities that prepare staff including supervisors, teachers, school aides, supervising \r\nschool aides, and secretaries for scoring or 2) to order supplies and technology to support scoring activities. \n\n\n\n\nFor June 2022, participating sites that operate during day and per session will receive \n\n$3,250\n\n.  \r\nSites that operate only during per session hours will receive \n\n$2,250\n\n. Sites that have agreed to score multiple exam content subject combinations will be allocated an additional \n\n$1,500\n\n. \r\nSites will receive an additional \n\n$200\n\n to print examination rating guides.\n\n\n\n\nFunds should be scheduled in the  \n\nTL Regents Distributed Scoring \n\n allocation category.\n\n\r\n\r\nQuestions regarding the scoring process should be directed to the Office of Assessment at \n\n\n\n\nregents@schools.nyc.gov.\n\n\n\n\nJune 2022 World Language Exam Hub Site Testing:\n\n\n\n\nWorld Language Exams, in 13 low incidence languages, are administered at designated hub sites throughout New York City. If students need to take an exam in one of these languages, they will be registered to take the exam at one of these central hub sites.\n\n\n\n\nThis allocation provides funds, to offset the additional costs associated with the organization and administration of this exam, to students not otherwise associated with that school. Allocations are based on the number of languages assessed at the hub site multiplied by the per diem rate of \n\n$199.27\n\n\n\n\nSchools receiving allocations can use those funds to offset any costs associated with the World Language Exam administration, including but not limited to hiring substitute teachers.\n\n\n\n\nIn June 2022, the Arabic language exams will be administered digitally. Hubs site supervisors administering this exam will require additional training and time for preparation. These hub sites will receive funds equivalent to a total of 10 hours of per session \n\n($565)\n\n to offset expenses incurred by the school for training and preparation, as well as\n\n $200 \n\nto order supplies and technology to support the administration of the Arabic exams.\n\n\n\n\nFunds should be scheduled in the  \n\nTL LOTE\n\n allocation category.\n\n\r\n\r\nQuestions regarding the scoring process shou ...

# %%
district_5_allocations = pd.read_csv(r'C:\Users\ebroh\BetaNYC\School Budgets\School-Budget-and-Allocations\data\district 5\allocation_district_5.csv')
district_5_allocations
# Out:
#       Unnamed: 0                                allocation_category  \
# 0              0                             AIDP Attendance Shared
# 1              1                             ARPA Academic Recovery
# 2              2                        ARPA Academic Recovery Arts
# 3              3  ARPA Academic Recovery SE After-School Instruc...
# 4              4               ARPA Academic Recovery SE Counseling
# ...          ...                                                ...
# 6901        6901                       TL Summer in the City Shared
# 6902        6902                            TL Translation Services
# 6903        6903                   TL Vision for School Improvement
# 6904        6904                    Universal PreK Quality Full-Day
# 6905        6905               Universal PreK Quality Full-Day Plus
#
#          amount location_code  fiscal_year
# 0     $ 150,490          M692         2022
# 1     $ 112,682          M692         2022
# 2      $ 28,171          M692         2022
# 3      $ 16,242          M692         2022
# 4       $ 2,223          M692         2022
# ...         ...           ...          ...
# 6901   $ 12,969          M030         2018
# 6902    $ 1,027          M030         2018
# 6903   $ 19,097          M030         2018
# 6904  $ 205,776          M030         2018
# 6905  $ 102,888          M030         2018
#
# [6906 rows x 5 columns]

# %%
M125_allocations = district_5_allocations[district_5_allocations['location_code'] == 'M125']
M125_allocations
# Out:
#       Unnamed: 0                                allocation_category  \
# 5282        5282                                         4K for All
# 5283        5283                             ARPA Academic Recovery
# 5284        5284            ARPA Academic Recovery AP Summer Rising
# 5285        5285                        ARPA Academic Recovery Arts
# 5286        5286  ARPA Academic Recovery SE After-School Instruc...
# ...          ...                                                ...
# 5517        5517                             TL Talented and Gifted
# 5518        5518                        TL Terminal and Paid Leaves
# 5519        5519                            TL Translation Services
# 5520        5520                   TL Vision for School Improvement
# 5521        5521                    Universal PreK Quality Full-Day
#
#          amount location_code  fiscal_year
# 5282  $ 475,301          M125         2022
# 5283   $ 79,229          M125         2022
# 5284   $ 17,990          M125         2022
# 5285   $ 19,807          M125         2022
# 5286   $ 24,609          M125         2022
# ...         ...           ...          ...
# 5517      $ 177          M125         2018
# 5518   $ 51,566          M125         2018
# 5519      $ 984          M125         2018
# 5520   $ 19,097          M125         2018
# 5521  $ 308,664          M125         2018
#
# [240 rows x 5 columns]

# %%
M125_2022 = M125_allocations[M125_allocations['fiscal_year'] == 2022]
M125_2022 = M125_2022.drop(columns=('Unnamed: 0'))
M125_allocation_categories = M125_2022['allocation_category'].unique()
all_2022_categories = []
for i in allocationCategories2022:
    all_2022_categories = all_2022_categories + i['Galaxy Titles']
overlap = [x for x in M125_allocation_categories if x not in all_2022_categories]
overlap
# Out:
# ['ARPA LA Initial Register Relief',
#  'ARPA LA MYA Register Relief',
#  'IDEA RS IEP Para',
#  'Rollover Smart Schools Bond Act',
#  'Title IIA Supplemental',
#  'TL FSF Post-IEP Support',
#  'TL Funds Over Formula',
#  'TL Itinerant Average Offset',
#  'TL Itinerant Staff Shared',
#  'TL NYSTL Library Books',
#  'TL Parent Coordinator',
#  'TL RS Speech Sixth Period Coverage',
#  'TL Terminal and Paid Leaves']

# %%
M125_2021 = M125_allocations[M125_allocations['fiscal_year'] == 2021]
M125_2021 = M125_2021.drop(columns=('Unnamed: 0'))
M125_allocation_categories = M125_2021['allocation_category'].unique()
all_2021_categories = []
for i in allocationCategories2021:
    all_2021_categories = all_2021_categories + i['Galaxy Titles']
overlap = [x for x in M125_allocation_categories if x not in all_2021_categories]   
overlap
# Out:
# ['4K for All',
#  'Title I SWP Summer in the City',
#  'Title IIA Supplemental',
#  'TL Arts Studio',
#  'TL Covid MY Register Loss Restoration',
#  'TL FSF Post-IEP Support',
#  'TL Funds Over Formula',
#  'TL HEW School Wellness Council',
#  'TL Implicit Bias Awareness',
#  'TL Instructional Leadership Framework',
#  'TL Periodic Assessment',
#  'TL Permanent Placement Incentive',
#  'TL RS Speech Sixth Period Coverage',
#  'TL School to School Summer Transfers Shared']

# %%
M125_2020 = M125_allocations[M125_allocations['fiscal_year'] == 2020]
M125_2020 = M125_2020.drop(columns=('Unnamed: 0'))
M125_allocation_categories = M125_2020['allocation_category'].unique()
all_2020_categories = []
for i in allocationCategories2020:
    all_2020_categories = all_2020_categories + i['Galaxy Titles']
overlap = [x for x in M125_allocation_categories if x not in all_2021_categories]   
overlap
# Out:
# ['FY20 Grant in Aid Assembly (08670)',
#  'TL Arts Studio',
#  'TL Funds Over Formula',
#  'TL Instructional Leadership Framework',
#  'TL MOSL',
#  'TL Permanent Placement Incentive',
#  'TL Potential Mid Year Adj to be Repaid',
#  'TL Prior Year Encumbrance',
#  'TL RS Speech Sixth Period Coverage',
#  'TL Terminal and Paid Leaves']

# %%
district_5_allocations = district_5_allocations.drop(columns = 'Unnamed: 0')
# Out:
#                                     allocation_category     amount  \
# 0                                AIDP Attendance Shared  $ 150,490
# 1                                ARPA Academic Recovery  $ 112,682
# 2                           ARPA Academic Recovery Arts   $ 28,171
# 3     ARPA Academic Recovery SE After-School Instruc...   $ 16,242
# 4                  ARPA Academic Recovery SE Counseling    $ 2,223
# ...                                                 ...        ...
# 6901                       TL Summer in the City Shared   $ 12,969
# 6902                            TL Translation Services    $ 1,027
# 6903                   TL Vision for School Improvement   $ 19,097
# 6904                    Universal PreK Quality Full-Day  $ 205,776
# 6905               Universal PreK Quality Full-Day Plus  $ 102,888
#
#      location_code  fiscal_year
# 0             M692         2022
# 1             M692         2022
# 2             M692         2022
# 3             M692         2022
# 4             M692         2022
# ...            ...          ...
# 6901          M030         2018
# 6902          M030         2018
# 6903          M030         2018
# 6904          M030         2018
# 6905          M030         2018
#
# [6906 rows x 4 columns]

# %%
district_5_allocations_2022 = district_5_allocations['allocation_category'][district_5_allocations['fiscal_year'] == 2022].unique()
district_5_allocations_2022
# Out:
# array(['AIDP Attendance Shared', 'ARPA Academic Recovery',
#        'ARPA Academic Recovery Arts',
#        'ARPA Academic Recovery SE After-School Instruction',
#        'ARPA Academic Recovery SE Counseling',
#        'ARPA Academic Recovery SE Intervention Training',
#        'ARPA Academic Recovery SE Planning Prep',
#        'ARPA Academic Recovery SE RS Related Services',
#        'ARPA Election Day Remote Planning',
#        'ARPA School COVID Planning Expansion',
#        'ARPA Vaccine Policy Coverage', 'Contract for Excellence FY 09 HS',
#        'CRRSA Computer Maintenance', 'CRRSA CRSE Arts Studio',
#        'CRRSA OTPS for PSAL', 'CRRSA Restoration Arts Studio',
#        'CRRSA Situation Room', 'High Need Support for Title I STH',
#        'IDEA RS IEP Para', 'Rollover Smart Schools Bond Act',
#        'Title I STH for Non Title I Schools',
#        'Title III Translation Services',
#        'Title IV Fall Reopening Planning Grant',
#        'Title IV Well Rounded ELA Math Support', 'TL 12-Month AP HS',
#        'TL CB School Staff', 'TL Computer Maintenance HS',
#        'TL CRRSA Surplus Rollover HS', 'TL CTE Programs HS',
#        'TL CTE WBL HS', 'TL E&E College Access 4 All HS',
#        'TL ELA/Math Student Support', 'TL Fair Student Funding HS',
#        'TL FSF Post-IEP Support HS', 'TL Funds Over Formula HS',
#        'TL MOSL', 'TL NYSTL Hardware HS', 'TL NYSTL Library Books HS',
#        'TL NYSTL Software HS', 'TL NYSTL Textbooks HS',
#        'TL Parent Coordinator HS', 'TL Parent Coordinator OTPS HS',
#        'TL Permanent Placement 2022', 'TL Permanent Placement Incentive',
#        'TL RS IEP Para', 'TL RS Mandated Counseling Shared',
#        'TL Sabbaticals', 'TL Situation Room',
#        'TL Summer Rising Discovery', 'TL Summer Rising Shared',
#        'TL Translation Services',
#        'ARPA Academic Recovery AP Summer Rising',
#        'ARPA Academic Recovery Para Summer Rising',
#        'ARPA Academic Recovery SE Support Summer Rising',
#        'ARPA Academic Recovery Social Worker',
#        'ARPA Academic Recovery Summer Rising',
#        'ARPA COVID Staffing Support', 'ARPA LA MYA Register Relief',
#        'ARPA Restorative Justice Action Teams', 'CRRSA SHSAT',
#        'Funds Pub Schl 359 - PS 670M - Per Session',
#        'High Need Support for Title I', 'OASAS Sub Abuse',
#        'Rollover MBK Exemplry Model D5M670 (08656)', 'Title I SWP',
#        'Title I SWP Carry Over',
#        'Title I SWP Carry Over Parent and Family Engage',
#        'Title I SWP Parent and Family Engagement', 'Title I SWP STH',
#        'Title I SWP Translation Services',
#        'Title IV Safe Healthy Counseling Summer Rising',
#        'TL CRRSA COVID MYA Register Relief HS',
#        'TL CRRSA FSF Floor Raise HS', 'TL E&E AP for All PSPD HS',
#        'TL E&E AP for All Support HS', 'TL FSF Floor Raise HS',
#        'TL RS IEP Teacher HS', 'TL RS Mandated Speech Shared',
#        'TL School to School Summer Rising Transfers Shared',
#        'TL Specialized Admissions HS', 'TL Summer Rising Support Shared',
#        'TL Temporary Shortfall Teachers', 'TL YMI Peer to Peer Mentoring',
#        '4K for All', 'Funds Pub Schl 302 - PS 517M - OTPS',
#        'Funds Pub Schl 390 - Arnhold Dance Program',
#        'TL Computer Maintenance', 'TL CRRSA COVID MYA Register Relief',
#        'TL CRRSA FSF Floor Raise', 'TL Fair Student Funding',
#        'TL FSF Floor Raise', 'TL NYSTL Hardware',
#        'TL NYSTL Library Books', 'TL NYSTL Software',
#        'TL NYSTL Textbooks', 'TL Parent Coordinator',
#        'TL Parent Coordinator OTPS',
#        'TL RS Occupational Therapist PS Shared',
#        'TL Specialized Admissions',
#        'TL Teacher Career Pathway - Subsidy Allocation',
#        'ARPA Academic Recovery CBO Support Summer Rising',
#        'ARPA Academic Recovery Community Schools Expansion',
#        'ARPA Academic Recovery Summer Rising ASD',
#        'ARPA LA Initial Register Relief', 'Contract for Excellence FY 09',
#        'TL COVID Register Relief', 'TL FSF Post-IEP Support',
#        'TL FSF School to School Transfers Shared HS',
#        'TL RS APE Teacher Shared', 'TL SE Specialized Programs ASD',
#        'TL Terminal and Paid Leaves',
#        'ARPA Academic Recovery NYSITELL Testing Admin',
#        'ARPA Computer Science for All',
#        'Funds Pub Schl 05 - PS 499M - OTPS',
#        'Funds Pub Schl 357 - PS 499M - Per Session',
#        'Funds Pub Schl 376 - PS 57R OTPS', 'OASAS Legislative Initiative',
#        'OASAS Sub Abuse OTPS', 'Rollover Title IV Community Coordinator',
#        'Title I 1003a TSI/CSI OTPS', 'Title I 1003a TSI/CSI PS',
#        'Title I CSI Participatory Budgeting', 'Title I Enhanced - EPL',
#        'Title I School Improvement 97 Enhanced Grant 11697',
#        'Title I SIG Enhanced Grant - High School Redesign',
#        'Title III LEP', 'Title IV Community Coordinator',
#        'TL Bridging the Gap', 'TL CFES RIS Return from Reassignment',
#        'TL CRRSA FSF Deficit Relief HS',
#        'TL ELL Initiative College Ready',
#        'TL RS Speech Sixth Period Coverage',
#        'ARPA Academic Recovery Arts Summer Rising',
#        'ARPA LA Permanent Placement',
#        'Funds Pub Schl 310 - High Qlty/Clinical Teach Prep',
#        'Rollover Private Grant 36 (02936)', 'TL CFES SBST Clustering',
#        'TL E&E Advanced Placement for All HS', 'TL SBST Shared',
#        'IC REV Physical Fitness CHAMPS SUPP UA 481/482',
#        'TL 09 C4E ICT HS', 'TL Champs', 'TL One-Time Allocations HS',
#        'TL Remote Teaching Program HS', 'TL Section 504',
#        'CRRSA Innovative Education Models', 'School Support Supplement',
#        'State Misc 05-Empire State After Sch Prog Rnd 2 D5',
#        'Title IIA Supplemental', 'TL Imagine Schools',
#        'TL Imagine Schools Per Session', 'TL Long Term Absence',
#        'TL NCSI After-School Tutoring', 'TL Host School HS',
#        'TL Regents Distributed Scoring', 'Rollover Private Grant 34',
#        'TL Continuous Improvement HS', 'TL COVID Register Relief HS',
#        '21st Century 62', '3K for All', '3K SCIS Classes',
#        'ARPA Academic Recovery SBST School Psychologist',
#        'CRRSA 3K for All Expansion',
#        'Private Grant 50 - UFTTC City Council Grant',
#        'Private Grant 99 Energy Demand', 'TL RS IEP Teacher',
#        'TL RS Physical Therapist PS Shared',
#        'AIDP STH School and Site Based Shared', 'IDEA SBST Shared',
#        'Pre-K SCIS Classes',
#        'Rollover Title I Schl Imprv 97 Enhance Grant 11697',
#        'Title I Enhanced - EDL', 'TL 09 C4E ICT',
#        'CRRSA Family Leadership',
#        'Funds Pub Schl 307 - Unrestricted School Support',
#        'TL Continuous Improvement Receivership HS', 'AIDP',
#        'Funds Pub Schl 355 - Carmell Hill',
#        'Title III Summer Rising ML Support', 'TL CRRSA Surplus Rollover',
#        'TL Lead Coach Teacher',
#        'CRRSA ELL/Special Needs Partner Arts Project OTPS',
#        'CRRSA Home Language Libraries', 'Title III Immigrant Carryover',
#        'Title IV Ed Tech', 'TL 12-Month AP',
#        'TL ELL/Special Needs Partner Arts Project OTPS',
#        'TL ELL/Special Needs Partner Arts Project PS',
#        'TL SE Specialized Program Bilingual',
#        'TL Student Club Advisor PS', 'TL Student Club Initiative OTPS',
#        'Rollover Title I 1003a TSI/CSI PS', 'TL Imagine Schools HS',
#        'CRRSA School Wellness', 'TL HEW School Wellness Council',
#        'TL Summer Rising ASD', 'TL UFT Officers-Reps and Chapt-Leaders',
#        'Rollover Title I 1003a TSI/CSI OTPS',
#        'Rollover Title I CSI Participatory Budgeting',
#        'TL Safe & Supportive Opportunity', 'Title I Enhanced - ICC',
#        'Title I Enhanced - Supporting New Principals',
#        'Foundation Grant 04-DANA CENTER Prof Lrng Partnrsp',
#        'TL Civics for All', 'TL Talented and Gifted',
#        'TL Funds Over Formula', 'TL Itinerant Average Offset',
#        'TL Itinerant Staff Shared',
#        'Funds Pub Schl 338 - Teaching Matters',
#        'TL CC Target Class Size Reduction Pilot',
#        'TL Robin Hood Libraries', 'TL CRRSA FSF Deficit Relief',
#        'Funds Pub Schl 23 - PS 30M - OTPS/Per Session',
#        'Title I SWP Post 630'], dtype=object)

# %%
memorandum_lookup = pd.DataFrame()
for memorandum_category in allocationCategories2022:
    for galaxy_title in memorandum_category['Galaxy Titles']:
        memorandum_lookup = pd.concat([memorandum_lookup, pd.DataFrame({'memorandum_category': [memorandum_category['Category']], 'galaxy_title': [galaxy_title], 'body': [memorandum_category['Body']]})], ignore_index = True)
memorandum_lookup
# Out:
#                                    memorandum_category  \
# 0    Arts Supplemental Funding through Fair Student...
# 1    Arts Supplemental Funding through Fair Student...
# 2            Career and Technical Education Supplement
# 3            Career and Technical Education Supplement
# 4            Career and Technical Education Supplement
# ..                                                 ...
# 366                 Implicit Bias Awareness Workshops
# 367                 Implicit Bias Awareness Workshops
# 368                 Implicit Bias Awareness Workshops
# 369                       Regents Distributed Scoring
# 370                       Regents Distributed Scoring
#
#                         galaxy_title  \
# 0           TL Fair Student Funding
# 1         TL Fair Student Funding HS
# 2                 TL CTE Programs HS
# 3                       TL STEAM HS
# 4            CRRSA E&E Early College
# ..                               ...
# 366    TL Implicit Bias Awareness CW
# 367              TL Implicit Bias PL
# 368           TL Implicit Bias PL CW
# 369  TL Regents Distributed Scoring
# 370                          TL LOTE
#
#                                                   body
# 0    \n\n\n\n\n\n\n\n\n\n\n\n\n\nNYCDOE Division of...
# 1    \n\n\n\n\n\n\n\n\n\n\n\n\n\nNYCDOE Division of...
# 2    \n\n\n\n\n\n\n\n\n\n\n\n\n\nNYCDOE Division of...
# 3    \n\n\n\n\n\n\n\n\n\n\n\n\n\nNYCDOE Division of...
# 4    \n\n\n\n\n\n\n\n\n\n\n\n\n\nNYCDOE Division of...
# ..                                                 ...
# 366  \n\n\n\n\n\n\n\n\n\n\n\n\n\nNYCDOE Division of...
# 367  \n\n\n\n\n\n\n\n\n\n\n\n\n\nNYCDOE Division of...
# 368  \n\n\n\n\n\n\n\n\n\n\n\n\n\nNYCDOE Division of...
# 369  \n\n\n\n\n\n\n\n\n\n\n\n\n\nNYCDOE Division of...
# 370  \n\n\n\n\n\n\n\n\n\n\n\n\n\nNYCDOE Division of...
#
# [371 rows x 3 columns]

# %%
memorandum_lookup.to_csv(r"C:\Users\ebroh\BetaNYC\School Budgets\School-Budget-and-Allocations\data\memorandum_lookups\memorandum_lookup2022_v2.csv")

# %%
#Added pre-commit file test (part 3)
