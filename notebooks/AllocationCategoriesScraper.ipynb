# %%
from bs4 import BeautifulSoup, NavigableString, Tag
import pandas as pd
import requests
import os
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service as ChromeService
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.support.ui import Select
from selenium.common.exceptions import NoSuchElementException
import numpy as np
import glob
import time
import re

# %%
url = 'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/am_fy22_erf1.htm'

chrome_options = webdriver.ChromeOptions()
#save any files in the current working directory
#prefs = {'download.default_directory' : os.getcwd()}
#chrome_options.add_argument("--headless")
#chrome_options.add_experimental_option('prefs', prefs)
service = ChromeService(executable_path=ChromeDriverManager().install())

driver = webdriver.Chrome(service = service, options=chrome_options)

driver.get(url)

# %%
url = 'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/am_fy22_pg1.htm'
url_prefix = 'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/'
urls = []
categories = []
#convert the webpage to soup
page = requests.get(url)
soup = BeautifulSoup(page.text, 'html.parser')
#find the webpage body with event details
table = soup.find('table')

ran = False

for row in table:
    try:
        for a in row.find_all('a', href=True):
            if a.text == 'Arts Supplemental Funding through Fair Student Funding':
                ran = True
            if ran:
                urls.append(url_prefix + a['href'])
                categories.append(a.text)
    except:
        continue

# %%
urls
# Out:
# ['https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam002.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam003.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam004.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam005.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam006.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam007.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam008.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam009.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam010.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam011.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam012.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam013.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam014.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam015.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam016.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam017.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam018.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam019.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam020.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam021.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam022.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam023.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam024.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam025.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam026.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam027.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam028.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam030.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam031.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam032.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam033.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam034.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam035.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam036.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam037.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam038.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam039.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam040.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam041.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam042.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam043.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam044.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam045.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/samna.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/FY2022_sam047.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam048.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam049.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam050.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam051.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam052.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam053.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam054.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam055.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam056.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam057.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam058.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam059.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam060.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam061.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam062.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam063.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam064.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam065.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam066.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam067.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam068.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam069.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam070.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam071.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam072.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam073.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam074.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam075.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam076.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam077.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam078.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam079.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam080.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam081.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam082.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam083.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam084.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam085.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam086.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam087.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam088.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam089.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam090.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam091.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam092.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam093.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam094.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam095.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam096.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam097.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam098.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam099.htm',
#  'https://www.nycenet.edu/offices/finance_schools/budget/DSBPO/allocationmemo/fy21_22/fy22_docs/fy2022_sam100.htm']

# %%
for i, category_title in enumerate(categories):
    categories[i] = re.sub("\\r|\\t|\\n","",category_title)
    
categories
# Out:
# ['Arts Supplemental Funding through Fair Student Funding',
#  'Career and Technical Education Supplement',
#  'ELA and Math Supplemental Support Services',
#  'Contract for Excellence',
#  'Collective Bargaining for School Based Staff',
#  'Summer Rising',
#  'FY 2021 Deficit Rollover Relief',
#  'School Budget Surplus Rollover',
#  'New York State Textbook Law (NYSTL), Library, Software and Hardware Allocation',
#  'Title I School Allocations',
#  'Title IIA Supplement',
#  'School Support Supplement',
#  'Title III Limited English Proficient (LEP) Program',
#  'Title IV Programs',
#  'Individualized Education Program (IEP)/Intervention Teacher Allocation',
#  ' Individualized Education Program (IEP) Paraprofessional Allocation',
#  'Mandated Related Services - (Speech, Counseling, OT/PT)',
#  'Adapted Physical Education',
#  'Specialized Programs - (ASD, BSE, ACES, Access)',
#  ' School Based IEP Team Staff',
#  'Support for Citywide Special Education',
#  'Section 504 Paraprofessional',
#  'Continuous Improvement Programs',
#  'OTPS for New Schools',
#  'Pre-K and 3-K for All Programs in District Schools',
#  'Pre-K and 3-K for All Programs in Pre-K Center Programs',
#  'Pre-K Family Worker Allocation',
#  'Robin Hood Libraries',
#  'Parent Coordinator Allocation',
#  'Salary Subsidy for Excess Staff Hired to Permanent Assignments',
#  'Success Via Apprenticeship (SVA)',
#  'District 75 Special Education Citywide Programs',
#  'District 79 Alternative Programs',
#  'Arts Funding Initiatives',
#  'Safe and Supportive Opportunity Program Expanded (SSOPE)',
#  'School COVID-19 Planning Supplement',
#  'Substance Abuse Violence Prevention',
#  'Counseling Initiatives',
#  ' AIDP Attendance Social Worker Community Schools',
#  ' AIDP and  Tax Levy (TL) Attendance Teachers',
#  ' AIDP Students in Temporary Housing (STH)',
#  ' Smart Schools Bond Act',
#  ' COVID-19 Register Relief',
#  ' Temporary Funds to Facilitate Excess Transactions',
#  ' Students Attending Institutional Facilities',
#  ' Alternate Learning Centers',
#  ' Targeted Literacy Supports and Class Size Reduction ',
#  ' City Council Member Items ',
#  ' Equity and Excellence:  Advanced Placement for All ',
#  ' Translation and Interpretation Services ',
#  ' NYSITELL Special Administration and Wellness Check ',
#  ' Computer Maintenance ',
#  ' Psychologist-In-Training ',
#  ' Equity and Excellence: College Access for All ',
#  ' ARPA School COVID-19 Staffing Supplement ',
#  ' Culturally Responsive Home Language Libraries ',
#  ' Carl D. Perkins Career and Technical Education (Perkins V) ',
#  ' Law Enforcement Academy ',
#  ' ARPA Academic Recovery ',
#  ' UFT Union Officers, District Representatives and Functional Chapter Leaders ',
#  ' Safety, Youth Development and School Climate and Wellness Initiatives ',
#  ' ARPA Vaccine Policy Coverage ',
#  ' Attendance Improvement/Dropout Prevention (AIDP) Discretionary Allocation ',
#  ' Teacher Leadership Programs ',
#  ' ARPA Community Schools Supplement ',
#  ' Specialized High School Admissions Testing ',
#  ' Remote Teaching Program Pilot ',
#  ' ARPA Academic Recovery Special Education Services ',
#  ' Long Term Absence Allocation ',
#  ' Postsecondary Readiness for ELLs Program ',
#  ' Career and Technical Education Expansion Initiatives ',
#  ' ARPA Academic Recovery Screener Administration and Support ',
#  ' Junior Reserve Officers Training Corps (JROTC) ',
#  ' Imagine Schools Innovation Grant ',
#  ' Measures of Student Learning ',
#  ' Identity-Based Student Clubs ',
#  ' College & Career Readiness for MLs/ELLs Initiative ',
#  ' Health Education, Physical Education, and Student Wellness Initiatives ',
#  ' Summer Rising - 12-Month Assistant Principal (AP) ',
#  ' Dream Squads',
#  ' Restorative Justice Action Teams',
#  ' Family Leadership and Digital Literacy for MLs/ELLs',
#  ' Sustainability Initiatives ',
#  ' School COVID-19 Register Relief Mid Year Adjustment ',
#  ' Title III Immigrant Programs ',
#  ' Educator Pipeline Programs ',
#  ' Civics for All: Participatory Budgeting ',
#  ' Innovative Education Models ',
#  ' Immigrant Ambassador Program ',
#  ' OTPS Allocation for PSAL Program ',
#  ' Transcript Maintenance ',
#  ' New School Planning Support ',
#  ' ARPA Computer Science for All ',
#  ' Gifted and Talented Programs ',
#  ' Mental Health Continuum ',
#  ' Community Schools Expansion Planning ',
#  ' Implicit Bias Awareness Workshops ',
#  ' Regents Distributed Scoring ']

# %%
chrome_options = webdriver.ChromeOptions()
#save any files in the current working directory
#prefs = {'download.default_directory' : os.getcwd()}
#chrome_options.add_argument("--headless")
#chrome_options.add_experimental_option('prefs', prefs)
service = ChromeService(executable_path=ChromeDriverManager().install())

driver = webdriver.Chrome(service = service, options=chrome_options)

driver.get(url)

# %%
categories_dict = {}

for i, url in enumerate(urls):
    driver.get(url)
    funding_titles = []
    elements = driver.find_elements(By.CSS_SELECTOR, '[style]')
    for element in elements:
        if ('fontweightbold' in (re.sub(r'\W+', '',element.get_attribute("style")).lower())) and ('colorblue' in (re.sub(r'\W+', '',element.get_attribute("style")).lower())):
            funding_titles.append(element.text)
    if '\n' in ''.join(funding_titles):
        temp = funding_titles.copy()
        for title in funding_titles:
            if '\n' in title:
                temp.remove(title)
                temp = temp + title.split('\n')
                funding_titles = temp
    categories_dict[i] = ({"Category": categories[i], "Galaxy Titles": funding_titles})

# %%
categories_dict
# Out:
# {0: {'Category': 'Arts Supplemental Funding through Fair Student Funding',
#   'Galaxy Titles': ['TL Fair Student Funding', 'TL Fair Student Funding HS']},
#  1: {'Category': 'Career and Technical Education Supplement',
#   'Galaxy Titles': ['TL CTE Programs HS',
#    'TL STEAM HS',
#    'CRRSA E&E Early College']},
#  2: {'Category': 'ELA and Math Supplemental Support Services',
#   'Galaxy Titles': ['TL ELA/Math Student Support',
#    'Title IV Well Rounded ELA Math Support']},
#  3: {'Category': 'Contract for Excellence',
#   'Galaxy Titles': ['Contract for Excellence FY 09',
#    'Contract for Excellence FY 09 HS',
#    'TL CB School Staff']},
#  4: {'Category': 'Collective Bargaining for School Based Staff',
#   'Galaxy Titles': ['TL CB School Staff',
#    'TL CB School Staff CW',
#    'TL CB School Staff D79']},
#  5: {'Category': 'Summer Rising',
#   'Galaxy Titles': ['ARPA, Title III, and Title IV',
#    'ARPA Academic Recovery Remote Summer Rising',
#    'ARPA Academic Recovery CBO Summer Rising',
#    'TL Summer Rising Shared',
#    'ARPA Academic Recovery Summer Rising',
#    'ARPA Academic Recovery Summer Rising',
#    'ARPA Academic Recovery Summer Rising',
#    'TL Summer Rising Shared',
#    'ARPA Academic Recovery Summer Rising',
#    'TL Summer Rising Shared',
#    'ARPA Academic Recovery AP Summer Rising',
#    'Title IV Safe Healthy Counseling Summer Rising',
#    'ARPA Academic Recovery Para Summer Rising',
#    'TL Summer Rising Shared',
#    'ARPA Academic Recovery Summer Rising',
#    'Title III Summer Rising ML Support.',
#    'ARPA Academic Recovery SE Support Summer Rising',
#    'ESY Summer Rising Services RS',
#    'TL RS ESY Summer Rising Services',
#    'TL Summer Rising ASD',
#    'ARPA Academic Recovery Summer Rising ASD',
#    'ARPA',
#    'TL Summer Rising Pre-K SE',
#    'TL Summer Rising Discovery Program',
#    'ARPA Academic Recovery CTE Summer Rising',
#    'ARPA Academic Recovery Arts Summer Rising',
#    'ARPA Academic Recovery WBL Summer Rising',
#    'TL Summer Rising Support Shared']},
#  6: {'Category': 'FY 2021 Deficit Rollover Relief',
#   'Galaxy Titles': ['TL CRRSA FSF Deficit Relief',
#    'TL CRRSA FSF Deficit Relief HS']},
#  7: {'Category': 'School Budget Surplus Rollover',
#   'Galaxy Titles': ['TL CRRSA Surplus Rollover (HS)(CW)',
#    'TL CRRSA Surplus Rollover, TL CRRSA Surplus Rollover HS, TL CRRSA Surplus Rollover CW']},
#  8: {'Category': 'New York State Textbook Law (NYSTL), Library, Software and Hardware Allocation',
#   'Galaxy Titles': []},
#  9: {'Category': 'Title I School Allocations',
#   'Galaxy Titles': ['Title I CSI Participatory Budget',
#    'Title I SWP',
#    'Title I Targeted Assistance',
#    'Title I SWP STH',
#    'Title I TA STH',
#    'Title I STH for Non Title I Schools',
#    'High Need Support for Title I',
#    'High Need Support for Title I STH',
#    'Title I SWP Parent and Family Engagement',
#    'Title I TA Parent and Family Engagement',
#    'Title I SWP Carry Over',
#    'Title I TA Carry Over',
#    'Title I SWP Carry Over Parent and Family Engage',
#    'Title I TA Carry Over Parent and Family Engage',
#    'Title I 1003a TSI/CSI PS',
#    'Title I 1003a TSI/CSI OTPS']},
#  10: {'Category': 'Title IIA Supplement', 'Galaxy Titles': []},
#  11: {'Category': 'School Support Supplement',
#   'Galaxy Titles': ['School Support Supplement']},
#  12: {'Category': 'Title III Limited English Proficient (LEP) Program',
#   'Galaxy Titles': ['Title III LEP', 'Title III LEP CW']},
#  13: {'Category': 'Title IV Programs',
#   'Galaxy Titles': ['Rollover Title IV Community Coordinator',
#    'Title IV Community Coordinator allocation',
#    'Title IV Community Coordinator.',
#    'Title IV Community Schools',
#    'Title IV Community Schools',
#    'Title IV ED Tech']},
#  14: {'Category': 'Individualized Education Program (IEP)/Intervention Teacher Allocation',
#   'Galaxy Titles': ['TL RS IEP TEACHER', 'TL RS IEP TEACHER HS.']},
#  15: {'Category': ' Individualized Education Program (IEP) Paraprofessional Allocation',
#   'Galaxy Titles': ['TL RS IEP Para',
#    'IDEA RS IEP',
#    'TL RS IEP Para',
#    'IDEA RS IEP',
#    'TL Interim Excess Para',
#    'TL RS IEP Para',
#    'IDEA RS IEP']},
#  16: {'Category': 'Mandated Related Services - (Speech, Counseling, OT/PT)',
#   'Galaxy Titles': ['TL RS Mandated Speech Shared',
#    'TL RS Mandated Speech D88',
#    'TL RS Mandated Counseling Shared',
#    'TL RS Occupational Therapist PS Shared',
#    'TL RS Physical Therapist PS Shared',
#    'TL RS Bronx Services Mandated Speech Shared',
#    'TL RS Bronx Services Occupational Therapist Shared',
#    'TL RS Bronx Services Physical Therapist PS Shared']},
#  17: {'Category': 'Adapted Physical Education',
#   'Galaxy Titles': ['TL RS APE Teacher Shared']},
#  18: {'Category': 'Specialized Programs - (ASD, BSE, ACES, Access)',
#   'Galaxy Titles': ['TL SE Specialized Programs ASD',
#    'TL SE Specialized Programs C4E ASD',
#    'TL Summer Rising ASD',
#    'TL SE Specialized Program ACES',
#    'TL SE Specialized Program BSE',
#    'TL SE Specialized Program Access',
#    'TL SE Specialized Program ICT']},
#  19: {'Category': ' School Based IEP Team Staff',
#   'Galaxy Titles': ['TL SBST Shared',
#    'TL SBST Shared D79',
#    'IDEA SBST Shared',
#    'IDEA SBST Shared D79',
#    'ARPA Academic Recovery SBST School Psychologist',
#    'ARPA Academic Recovery SBST Family Worker',
#    'IDEA SBST Shared, IDEA SBST Shared D79',
#    'ARPA Academic Recovery SBST School Psychologist',
#    'TL SBST Shared, TL SBST Shared D79',
#    'TL SBST Shared, TL SBST Shared D79',
#    'ARPA Academic Recovery SBST Family Worker',
#    'TL SBST Shared, TL SBST Shared D79',
#    'IDEA SBST Shared',
#    'IDEA SBST Shared D79',
#    'ARPA Academic Recovery SBST School Psychologist',
#    'TL SBST Shared',
#    'TL SBST Shared D79']},
#  20: {'Category': 'Support for Citywide Special Education',
#   'Galaxy Titles': ['TL Vision and Hearing Coverage',
#    'TL Part Time Inclusion']},
#  21: {'Category': 'Section 504 Paraprofessional',
#   'Galaxy Titles': ['TL Section 504']},
#  22: {'Category': 'Continuous Improvement Programs',
#   'Galaxy Titles': ['TL CB School Staff',
#    'TL Continuous Improvement',
#    'TL Continuous Improvement HS',
#    'TL Continuous Improvement Receivership',
#    'TL Continuous Improvement Receivership HS']},
#  23: {'Category': 'OTPS for New Schools',
#   'Galaxy Titles': ['TL OTPS New Schools', 'TL OTPS New Schools HS']},
#  24: {'Category': 'Pre-K and 3-K for All Programs in District Schools',
#   'Galaxy Titles': ['4-K for All',
#    'Contract for Excellence FY 09 Pre-K',
#    '4K for ALL',
#    'Pre-K SCIS Classes',
#    'Pre-K Special Classes',
#    'RS Pre-K Special Classes',
#    '3-K for All',
#    '3K SCIS Classes',
#    'CRRSA 3K for ALL Expansion']},
#  25: {'Category': 'Pre-K and 3-K for All Programs in Pre-K Center Programs',
#   'Galaxy Titles': ['4-K Pre-K Center',
#    'Pre-K Medicaid Speech Providers',
#    '4K Pre-K Center',
#    '3K Pre-K Center',
#    'CRRSA 3K Pre-K Center Expansion',
#    'Pre-K SCIS Classes',
#    'Pre-K Special Ed Classes',
#    'RS Pre-K Special Classes']},
#  26: {'Category': 'Pre-K Family Worker Allocation',
#   'Galaxy Titles': ['4K for All']},
#  27: {'Category': 'Robin Hood Libraries',
#   'Galaxy Titles': ['TL Robin Hood Libraries.']},
#  28: {'Category': 'Parent Coordinator Allocation',
#   'Galaxy Titles': ['TL Parent Coordinator HS - Flexible',
#    'TL Parent Coordinator HS allocation',
#    'TL Parent Coordinator TL Parent Coordinator - Contracted',
#    'TL Parent Coordinator HS TL Parent Coordinator HS - Contracted',
#    'TL Parent Coordinator HS - Flexible',
#    'TL Parent Coordinator CW',
#    'TL Parent Coordinator OTPS',
#    'TL Parent Coordinator OTPS HS',
#    'TL Parent Coordinator OTPS CW']},
#  29: {'Category': 'Salary Subsidy for Excess Staff Hired to Permanent Assignments',
#   'Galaxy Titles': ['TL Permanent Placement Incentive',
#    'TL Permanent Placement 2022']},
#  30: {'Category': 'Success Via Apprenticeship (SVA)',
#   'Galaxy Titles': ['TL SVA HS']},
#  31: {'Category': 'District 75 Special Education Citywide Programs',
#   'Galaxy Titles': ['TL Instructional Programs CW',
#    'TL Supplemental Instructional Support CW',
#    'TL RS Attendance CW',
#    'TL BMS CW',
#    'TL COACH CW',
#    'TL RS ESL CW',
#    'TL Home and Hospital',
#    'TL Project Arts CW',
#    'TL RS Related Services CW',
#    'TL Pre-K Program Support CW',
#    'TL RS Pre-K Related Services CW',
#    'TL Travel Training CW',
#    'TL RS IEP Para CW',
#    'IDEA RS IEP Para CW',
#    'TL RS Speech CW',
#    'TL RS Counseling CW',
#    'TL RS OT CW',
#    'TL RS PT CW',
#    'TL Supplemental Instructional Services CW',
#    'TL Specialized Equipment CW',
#    'TL RS BUS PARAS CW',
#    'TL RS Therapist OTPS CW',
#    'TL Instructional Programs CW',
#    'TL Supplemental Instructional Support CW',
#    'TL RS Related Services CW',
#    'TL Home & Hospitals',
#    'Tax Levy Pre-K Program Support',
#    'TL RS Pre-K Related Services',
#    'TL RS Therapist OTPS CW',
#    'TL Specialized Equipment CW',
#    'TL RS IEP Para CW',
#    'IDEA RS IEP Para CW',
#    'TL RS OT CW',
#    'TL RS PT CW',
#    'TL RS Speech CW',
#    'TL RS BUS PARAS CW',
#    'TL RS Counseling C',
#    'TL RS Attendance CW',
#    'TL BMS CW',
#    'TL Travel Training CW and',
#    'TL RS ESL CW']},
#  32: {'Category': 'District 79 Alternative Programs', 'Galaxy Titles': []},
#  33: {'Category': 'Arts Funding Initiatives',
#   'Galaxy Titles': ['TL High School Screened Arts Program',
#    'TL High School Screened Arts Program Supplement',
#    'TL HS Screened Arts Designation',
#    'TL Broadway Junior Arts Supplement, TL Broadway Junior Arts Supplement HS, TL Broadway Junior Arts Supplement CW, TL Broadway Junior Arts Supplement OTPS, TL Broadway Junior Arts Supplement OTPS HS,',
#    'TL Broadway Junior Arts Supplement OTPS CW',
#    'TL ELL/Special Needs Partner Arts Project OTPS, TL ELL/Special Needs Partner Arts Project OTPS HS, TL ELL/Special Needs Partner Arts Project OTPS CW or CRRSA ELL/Special Needs Partner Arts Project OTPS',
#    'TL ELL/Special Needs Partner Arts Project PS, TL ELL/Special Needs Partner Arts Project PS HS or TL ELL/Special Needs Partner Arts Project PS CW',
#    'TL Parent and Arts Partner Program OTPS, TL Parent and Arts Partner Program OTPS HS or TL Parent and Arts Partner Program OTPS CW',
#    'TL Parent and Arts Partner Program PS, TL Parent and Arts Partner Program PS HS or TL Parent and Arts Partner Program PS CW',
#    'CRRSA Restoration Arts Studio',
#    'CRRSA CRSE Arts Studio',
#    'TL Virtual Audition.']},
#  34: {'Category': 'Safe and Supportive Opportunity Program Expanded (SSOPE)',
#   'Galaxy Titles': ['TL SAFE & SUPPORTIVE OPPORTUNITY.']},
#  35: {'Category': 'School COVID-19 Planning Supplement',
#   'Galaxy Titles': ['Title IV Fall Reopening Planning Grant',
#    'ARPA School COVID Planning Expansion',
#    'ARPA Election Day Remote Planning',
#    'TL Situation Room',
#    'TL Situation Room CW',
#    'Pre-K Center Situation Room',
#    'CRRSA Situation Room']},
#  36: {'Category': 'Substance Abuse Violence Prevention',
#   'Galaxy Titles': ['OASAS SUB ABUSE',
#    'OASAS LEGISLATIVE INITIATIVE',
#    'OASAS SUB ABUSE OTPS']},
#  37: {'Category': 'Counseling Initiatives',
#   'Galaxy Titles': ['TL Social Worker Support High Need',
#    'ARPA Academic Recovery Social Worker',
#    'TL Guidance Support High Need',
#    'TL Guidance Support High Need HS.',
#    'TL Guidance Support',
#    'TL Guidance Support HS.',
#    'TL Bridging the Gap',
#    'TL Bridging the Gap CW',
#    'TL Thrive School Response Clinicians',
#    'TL Single Shepherd Counseling Services',
#    'TL Single Shepherd SW']},
#  38: {'Category': ' AIDP Attendance Social Worker Community Schools',
#   'Galaxy Titles': ['AIDP Community School Social Workers']},
#  39: {'Category': ' AIDP and  Tax Levy (TL) Attendance Teachers',
#   'Galaxy Titles': ['TL Attendance Shared', 'AIDP Attendance Shared']},
#  40: {'Category': ' AIDP Students in Temporary Housing (STH)',
#   'Galaxy Titles': ['AIDP STH School and Site Based Shared']},
#  41: {'Category': ' Smart Schools Bond Act',
#   'Galaxy Titles': ['Smart Schools Bond Act']},
#  42: {'Category': ' COVID-19 Register Relief',
#   'Galaxy Titles': ['TL COVID Register Relief',
#    'TL COVID Register Relief HS']},
#  43: {'Category': ' Temporary Funds to Facilitate Excess Transactions',
#   'Galaxy Titles': []},
#  44: {'Category': ' Students Attending Institutional Facilities',
#   'Galaxy Titles': ['Title I Neglected D79', 'Title I Delinquent D79']},
#  45: {'Category': ' Alternate Learning Centers',
#   'Galaxy Titles': ['TL Borough Suspension Center']},
#  46: {'Category': ' Targeted Literacy Supports and Class Size Reduction ',
#   'Galaxy Titles': ['TL CC Target Class Size Reduction Pilot']},
#  47: {'Category': ' City Council Member Items ',
#   'Galaxy Titles': ['TL City Council Member Items',
#    'TL City Council Member Items Vendors']},
#  48: {'Category': ' Equity and Excellence:  Advanced Placement for All ',
#   'Galaxy Titles': ['TL E&E Advanced Placement for All HS',
#    'TL E&E AP for All PSPD HS',
#    'TL E&E AP for All Support HS']},
#  49: {'Category': ' Translation and Interpretation Services ',
#   'Galaxy Titles': ['TL Translation Services',
#    'TL Translation Services CW',
#    'Title I SWP Translation Services',
#    'Title I Targeted Assistance Translation Services',
#    'Title III Translation Services']},
#  50: {'Category': ' NYSITELL Special Administration and Wellness Check ',
#   'Galaxy Titles': ['ARPA Academic Recovery NYSITELL Testing Admin']},
#  51: {'Category': ' Computer Maintenance ',
#   'Galaxy Titles': ['TL Computer Maintenance',
#    'TL Computer Maintenance HS',
#    'TL Computer Maintenance CW',
#    'CRRSA Computer Maintenance']},
#  52: {'Category': ' Psychologist-In-Training ',
#   'Galaxy Titles': ['TL SBST PITs Shared']},
#  53: {'Category': ' Equity and Excellence: College Access for All ',
#   'Galaxy Titles': ['TL E&E College Access 4 ALL HS',
#    'TL E&E College Access 4 ALL CW']},
#  54: {'Category': ' ARPA School COVID-19 Staffing Supplement ',
#   'Galaxy Titles': ['ARPA COVID Staffing Support']},
#  55: {'Category': ' Culturally Responsive Home Language Libraries ',
#   'Galaxy Titles': ['CRRSA Home Language Libraries']},
#  56: {'Category': ' Carl D. Perkins Career and Technical Education (Perkins V) ',
#   'Galaxy Titles': ['Perkins V.']},
#  57: {'Category': ' Law Enforcement Academy ',
#   'Galaxy Titles': ['TL Justice Center Law Enforcement HS']},
#  58: {'Category': ' ARPA Academic Recovery ',
#   'Galaxy Titles': ['ARPA Academic Recovery', 'ARPA Academic Recovery Arts']},
#  59: {'Category': ' UFT Union Officers, District Representatives and Functional Chapter Leaders ',
#   'Galaxy Titles': ['TL UFT Officers - Reps and Chapt Leaders',
#    'TL UFT Officers - Reps and Chapt Leaders HS',
#    'TL UFT Officers - Reps and Chapt Leaders CW']},
#  60: {'Category': ' Safety, Youth Development and School Climate and Wellness Initiatives ',
#   'Galaxy Titles': ['TL NYC MENTORING PS',
#    'TL NYC MENTORING OTPS',
#    'TL NCSI After-School Tutoring',
#    'TL NCSI After-School Tutoring CW.']},
#  61: {'Category': ' ARPA Vaccine Policy Coverage ',
#   'Galaxy Titles': ['ARPA Vaccine Policy Coverage']},
#  62: {'Category': ' Attendance Improvement/Dropout Prevention (AIDP) Discretionary Allocation ',
#   'Galaxy Titles': ['AIDP', 'AIDP']},
#  63: {'Category': ' Teacher Leadership Programs ',
#   'Galaxy Titles': ['TL Teacher Career Pathways - Subsidy Allocation (CW)',
#    'ARPA Bronx Teacher Leadership Teams',
#    'TL Lead Coach Teacher']},
#  64: {'Category': ' ARPA Community Schools Supplement ',
#   'Galaxy Titles': ['ARPA Community School Supplement']},
#  65: {'Category': ' Specialized High School Admissions Testing ',
#   'Galaxy Titles': ['TL Specialized Admissions HS', 'CRRSA SHSAT']},
#  66: {'Category': ' Remote Teaching Program Pilot ',
#   'Galaxy Titles': ['TL Remote Teaching Program HS']},
#  67: {'Category': ' ARPA Academic Recovery Special Education Services ',
#   'Galaxy Titles': ['ARPA Academic Recovery SE After-School Instruction:',
#    'ARPA Academic Recovery SE Intervention Training:',
#    'ARPA Academic Recovery SE RS Related Services:',
#    'ARPA Academic Recovery SE Counseling:',
#    'ARPA Academic Recovery SE Planning Prep:',
#    'ARPA Academic Recovery SE After-School Instruction',
#    'ARPA Academic Recovery SE Intervention Training',
#    'ARPA Academic Recovery SE RS Related Services',
#    'ARPA Academic Recovery SE Counseling',
#    'ARPA Academic Recovery SE Planning Prep',
#    'ARPA Academic Recovery SE After-School Instruction',
#    'ARPA Academic Recovery SE Intervention Training',
#    'ARPA Academic Recovery SE RS Related Services',
#    'ARPA Academic Recovery SE Counseling',
#    'ARPA Academic Recovery SE Planning Prep']},
#  68: {'Category': ' Long Term Absence Allocation ',
#   'Galaxy Titles': ['TL ASA HH',
#    'ARPA Vaccine Policy Coverage',
#    'TL Long Term Absence']},
#  69: {'Category': ' Postsecondary Readiness for ELLs Program ',
#   'Galaxy Titles': ['ARPA Academic Recovery PREP']},
#  70: {'Category': ' Career and Technical Education Expansion Initiatives ',
#   'Galaxy Titles': ['TL CTE WBL HS.']},
#  71: {'Category': ' ARPA Academic Recovery Screener Administration and Support ',
#   'Galaxy Titles': ['ARPA Academic Recovery Screener']},
#  72: {'Category': ' Junior Reserve Officers Training Corps (JROTC) ',
#   'Galaxy Titles': ['TL ROTC']},
#  73: {'Category': ' Imagine Schools Innovation Grant ',
#   'Galaxy Titles': ['TL Imagine Schools',
#    'TL Imagine Schools CW',
#    'TL Imagine Schools Per Session']},
#  74: {'Category': ' Measures of Student Learning ',
#   'Galaxy Titles': ['TL MOSL']},
#  75: {'Category': ' Identity-Based Student Clubs ',
#   'Galaxy Titles': ['TL Student Club Advisor PS (CW)',
#    'TL Student Club Initiative OTPS (CW)']},
#  76: {'Category': ' College & Career Readiness for MLs/ELLs Initiative ',
#   'Galaxy Titles': ['TL ELL Initiative College Ready']},
#  77: {'Category': ' Health Education, Physical Education, and Student Wellness Initiatives ',
#   'Galaxy Titles': ['TL CHAMPS (CW)',
#    'TL HEW School Wellness Council (CW)',
#    'CRRSA School Wellness']},
#  78: {'Category': ' Summer Rising - 12-Month Assistant Principal (AP) ',
#   'Galaxy Titles': ['TL 12-Month AP', 'TL 12-Month AP HS']},
#  79: {'Category': ' Dream Squads', 'Galaxy Titles': ['CRRSA Dream Squad']},
#  80: {'Category': ' Restorative Justice Action Teams',
#   'Galaxy Titles': ['ARPA Restorative Justice Action Teams']},
#  81: {'Category': ' Family Leadership and Digital Literacy for MLs/ELLs',
#   'Galaxy Titles': ['CRRSA Family Leadership']},
#  82: {'Category': ' Sustainability Initiatives ',
#   'Galaxy Titles': ['Private Grant 99 Energy Demand']},
#  83: {'Category': ' School COVID-19 Register Relief Mid Year Adjustment ',
#   'Galaxy Titles': ['TL COVID MYA Register Relief',
#    'TL COVID MYA Register Relief HS',
#    'TL CRRSA COVID MYA Register Relief',
#    'TL CRRSA COVID MYA Register Relief HS']},
#  84: {'Category': ' Title III Immigrant Programs ',
#   'Galaxy Titles': ['Title III Immigrant', 'Title III Immigrant Carryover']},
#  85: {'Category': ' Educator Pipeline Programs ',
#   'Galaxy Titles': ['TL Urban Teacher Residency (HS)']},
#  86: {'Category': ' Civics for All: Participatory Budgeting ',
#   'Galaxy Titles': ['TL Civics for All (CW)']},
#  87: {'Category': ' Innovative Education Models ',
#   'Galaxy Titles': ['CRRSA Innovative Education Models']},
#  88: {'Category': ' Immigrant Ambassador Program ',
#   'Galaxy Titles': ['ARPA Academic Recovery Immigrant Ambassador']},
#  89: {'Category': ' OTPS Allocation for PSAL Program ',
#   'Galaxy Titles': ['CRRSA OTPS for PSAL']},
#  90: {'Category': ' Transcript Maintenance ',
#   'Galaxy Titles': ['TL Host Schools HS']},
#  91: {'Category': ' New School Planning Support ',
#   'Galaxy Titles': ['TL New School Planning']},
#  92: {'Category': ' ARPA Computer Science for All ',
#   'Galaxy Titles': ['ARPA Computer Science for All.']},
#  93: {'Category': ' Gifted and Talented Programs ',
#   'Galaxy Titles': ['TL Talented and Gifted']},
#  94: {'Category': ' Mental Health Continuum ',
#   'Galaxy Titles': ['TL MH Continuum Resources',
#    'TL MH Continuum Resources CW']},
#  95: {'Category': ' Community Schools Expansion Planning ',
#   'Galaxy Titles': ['ARPA Academic Recovery Community Schools Expansion.']},
#  96: {'Category': ' Implicit Bias Awareness Workshops ',
#   'Galaxy Titles': ['TL Implicit Bias Awareness',
#    'TL Implicit Bias Awareness CW',
#    'TL Implicit Bias PL',
#    'TL Implicit Bias PL CW']},
#  97: {'Category': ' Regents Distributed Scoring ',
#   'Galaxy Titles': ['TL Regents Distributed Scoring', 'TL LOTE']}}
